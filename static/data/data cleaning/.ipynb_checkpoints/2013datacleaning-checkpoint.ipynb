# %%
import pandas as pd
import numpy as np

# %%
# import csv
raw_data = "FBI_crime_data_raw/2013.csv"
raw_data_df = pd.read_csv(raw_data)

raw_data_df.columns
# Out:
# Index(['State', 'City', 'Unnamed: 2', 'Population1', 'Violent\ncrime',
#        'Murder', 'Rape', 'Robbery', 'Aggravated\nassault', 'Property\ncrime',
#        'Burglary', 'Larceny-\ntheft', 'Motor\nvehicle\ntheft', 'Arson2',
#        'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')

# %%
raw_data_df = raw_data_df.rename(columns={"Unnamed: 2": "Year", "Population1":"Population", "Violent\ncrime":"Violent Crime", "Forcible\nrape":"Rape", "Aggravated\nassault":"Aggravated Assault", "Property\ncrime":"Property Crime", "Larceny-\ntheft":"Larceny Theft", "Motor\nvehicle\ntheft":"Motor Vehicle Theft", "Arson2":"Arson"})
raw_data_df
# Out:
#        State         City    Year Population Violent Crime Murder Rape  \
# 0    ALABAMA  BIRMINGHAM3  2012.0    213,266           NaN    NaN  NaN
# 1        NaN          NaN  2013.0        NaN         1,468     39   79
# 2        NaN   HUNTSVILLE  2012.0    183,691           813      1   46
# 3        NaN          NaN  2013.0        NaN           793     12   22
# 4        NaN   MOBILE3, 4  2012.0    251,516           NaN    NaN  NaN
# ..       ...          ...     ...        ...           ...    ...  ...
# 586      NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 587      NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 588      NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 589      NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 590      NaN          NaN     NaN        NaN           NaN    NaN
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# 0       NaN                NaN            NaN      NaN           NaN
# 1       455                895          6,357    1,942         3,964
# 2       231                535          4,606    1,095         3,136
# 3       208                551          4,347      893         3,149
# 4       NaN                NaN            NaN      NaN           NaN
# ..      ...                ...            ...      ...           ...
# 586     NaN                NaN            NaN      NaN           NaN
# 587     NaN                NaN            NaN      NaN           NaN
# 588     NaN                NaN            NaN      NaN           NaN
# 589     NaN                NaN            NaN                    NaN
# 590     NaN                NaN            NaN      NaN           NaN
#
#     Motor Vehicle Theft  Arson Unnamed: 14 Unnamed: 15
# 0                   NaN    NaN         NaN         NaN
# 1                   451    NaN         NaN         NaN
# 2                   375   10.0         NaN         NaN
# 3                   305    NaN         NaN         NaN
# 4                   NaN    NaN         NaN         NaN
# ..                  ...    ...         ...         ...
# 586                 NaN    NaN         NaN         NaN
# 587                 NaN    NaN         NaN         NaN
# 588                 NaN    NaN         NaN         NaN
# 589                 NaN    NaN         NaN         NaN
# 590                 NaN    NaN         NaN         NaN
#
# [591 rows x 16 columns]

# %%
raw_data_df = raw_data_df.drop(columns=["Unnamed: 14", "Unnamed: 15"])
raw_data_df
# Out:
#        State         City    Year Population Violent Crime Murder Rape  \
# 0    ALABAMA  BIRMINGHAM3  2012.0    213,266           NaN    NaN  NaN
# 1        NaN          NaN  2013.0        NaN         1,468     39   79
# 2        NaN   HUNTSVILLE  2012.0    183,691           813      1   46
# 3        NaN          NaN  2013.0        NaN           793     12   22
# 4        NaN   MOBILE3, 4  2012.0    251,516           NaN    NaN  NaN
# ..       ...          ...     ...        ...           ...    ...  ...
# 586      NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 587      NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 588      NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 589      NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 590      NaN          NaN     NaN        NaN           NaN    NaN
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# 0       NaN                NaN            NaN      NaN           NaN
# 1       455                895          6,357    1,942         3,964
# 2       231                535          4,606    1,095         3,136
# 3       208                551          4,347      893         3,149
# 4       NaN                NaN            NaN      NaN           NaN
# ..      ...                ...            ...      ...           ...
# 586     NaN                NaN            NaN      NaN           NaN
# 587     NaN                NaN            NaN      NaN           NaN
# 588     NaN                NaN            NaN      NaN           NaN
# 589     NaN                NaN            NaN                    NaN
# 590     NaN                NaN            NaN      NaN           NaN
#
#     Motor Vehicle Theft  Arson
# 0                   NaN    NaN
# 1                   451    NaN
# 2                   375   10.0
# 3                   305    NaN
# 4                   NaN    NaN
# ..                  ...    ...
# 586                 NaN    NaN
# 587                 NaN    NaN
# 588                 NaN    NaN
# 589                 NaN    NaN
# 590                 NaN    NaN
#
# [591 rows x 14 columns]

# %%
# replace empty strings with NaN
raw_data_df['State'] = raw_data_df['State'].replace(' ', np.nan).ffill()
raw_data_df['City'] = raw_data_df['City'].replace(' ', np.nan).ffill()

# %%
# list of values of State column
States = raw_data_df['State'].unique()
States
# Out:
# array(['ALABAMA', 'ALASKA', 'ARIZONA', 'ARKANSAS5', 'CALIFORNIA',
#        'COLORADO5', 'CONNECTICUT', 'FLORIDA5', 'GEORGIA', 'IDAHO5',
#        'ILLINOIS', 'INDIANA', 'IOWA5', 'KANSAS', 'KENTUCKY5', 'LOUISIANA',
#        'MARYLAND', 'MASSACHUSETTS', 'MICHIGAN5', 'MINNESOTA5',
#        'MISSISSIPPI', 'MISSOURI5', 'MONTANA5', 'NEBRASKA', 'NEVADA',
#        'NEW HAMPSHIRE5', 'NEW JERSEY', 'NEW YORK6', 'NORTH CAROLINA',
#        'NORTH DAKOTA5', 'OHIO', 'OKLAHOMA', 'OREGON', 'PENNSYLVANIA5',
#        'RHODE ISLAND5', 'SOUTH CAROLINA5', 'TENNESSEE5', 'TEXAS', 'UTAH5',
#        'VIRGINIA5', 'WASHINGTON', 'WISCONSIN5'], dtype=object)

# %%
# list of values of city column
Cities = raw_data_df['City'].unique()
Cities
# Out:
# array(['BIRMINGHAM3', 'HUNTSVILLE', 'MOBILE3, 4', 'MONTGOMERY',
#        'ANCHORAGE5', 'CHANDLER6', 'GILBERT5', 'GLENDALE', 'MESA ',
#        'PEORIA', 'PHOENIX7', 'SCOTTSDALE', 'SURPRISE', 'TEMPE     ',
#        'TUCSON6, 8', 'LITTLE ROCK', 'ANAHEIM', 'ANTIOCH', 'BAKERSFIELD',
#        'BERKELEY', 'BURBANK', 'CARLSBAD', 'CHULA VISTA', 'CONCORD',
#        'CORONA ', 'COSTA MESA ', 'DALY CITY', 'DOWNEY', 'EL CAJON',
#        'ELK GROVE', 'EL MONTE', 'ESCONDIDO ', 'FAIRFIELD', 'FONTANA ',
#        'FREMONT ', 'FRESNO', 'FULLERTON', 'GARDEN GROVE', 'HAYWARD',
#        'HUNTINGTON BEACH', 'INGLEWOOD', 'IRVINE', 'LANCASTER',
#        'LONG BEACH ', 'LOS ANGELES', 'MODESTO ', 'MORENO VALLEY',
#        'MURRIETA', 'NORWALK ', 'OAKLAND', 'OCEANSIDE', 'ONTARIO',
#        'ORANGE', 'OXNARD ', 'PALMDALE', 'PASADENA', 'POMONA',
#        'RANCHO CUCAMONGA ', 'RIALTO', 'RICHMOND', 'RIVERSIDE',
#        'ROSEVILLE', 'SACRAMENTO', 'SALINAS', 'SAN BERNARDINO ',
#        'SAN DIEGO', 'SAN FRANCISCO', 'SAN JOSE   ', 'SANTA ANA',
#        'SANTA CLARA', 'SANTA CLARITA', 'SANTA MARIA', 'SANTA ROSA',
#        'SIMI VALLEY', 'STOCKTON', 'SUNNYVALE', 'TEMECULA',
#        'THOUSAND OAKS', 'TORRANCE', 'VALLEJO', 'VENTURA', 'VICTORVILLE',
#        'VISALIA', 'WEST COVINA', 'ARVADA', 'AURORA', 'BOULDER',
#        'CENTENNIAL', 'COLORADO SPRINGS', 'DENVER', 'FORT COLLINS',
#        'LAKEWOOD', 'PUEBLO', 'THORNTON6', 'WESTMINSTER', 'BRIDGEPORT',
#        'HARTFORD', 'NEW HAVEN5', 'STAMFORD5', 'WATERBURY', 'CAPE CORAL',
#        'CLEARWATER', 'CORAL SPRINGS', 'FORT LAUDERDALE', 'GAINESVILLE',
#        'HIALEAH', 'JACKSONVILLE', 'MIAMI', 'MIAMI GARDENS', 'MIRAMAR',
#        'ORLANDO', 'PALM BAY', 'PEMBROKE PINES ', 'POMPANO BEACH',
#        'PORT ST. LUCIE', 'ST. PETERSBURG', 'TALLAHASSEE ', 'TAMPA ',
#        'WEST PALM BEACH', 'ATHENS-CLARKE COUNTY', 'ATLANTA', 'COLUMBUS',
#        'SAVANNAH-CHATHAM METROPOLITAN', 'BOISE  ', 'CHICAGO9', 'ELGIN',
#        'JOLIET', 'NAPERVILLE', 'ROCKFORD5', 'SPRINGFIELD', 'FORT WAYNE5',
#        'INDIANAPOLIS5', 'SOUTH BEND5', 'CEDAR RAPIDS', 'KANSAS CITY',
#        'OVERLAND PARK', 'TOPEKA', 'WICHITA5', 'LEXINGTON5',
#        'LOUISVILLE METRO', 'BATON ROUGE', 'LAFAYETTE', 'NEW ORLEANS',
#        'SHREVEPORT', 'BALTIMORE', 'BOSTON', 'CAMBRIDGE5', 'LOWELL5',
#        'SPRINGFIELD5', 'WORCESTER5', 'ANN ARBOR', 'DETROIT', 'FLINT',
#        'GRAND RAPIDS', 'LANSING', 'STERLING HEIGHTS', 'WARREN',
#        'MINNEAPOLIS', 'ST. PAUL', 'JACKSON', 'COLUMBIA', 'INDEPENDENCE',
#        'ST. LOUIS', 'BILLINGS', 'LINCOLN', 'OMAHA', 'HENDERSON',
#        'LAS VEGAS METROPOLITAN \n  POLICE DEPARTMENT     ',
#        'NORTH LAS VEGAS', 'RENO', 'MANCHESTER', 'EDISON TOWNSHIP',
#        'ELIZABETH', 'JERSEY CITY', 'NEWARK', 'PATERSON',
#        'WOODBRIDGE TOWNSHIP', 'AMHERST TOWN', 'BUFFALO', 'NEW YORK',
#        'ROCHESTER', 'SYRACUSE', 'YONKERS', 'CARY',
#        'CHARLOTTE-MECKLENBURG', 'DURHAM', 'FAYETTEVILLE', 'GREENSBORO',
#        'HIGH POINT', 'RALEIGH', 'WILMINGTON', 'WINSTON-SALEM', 'FARGO',
#        'AKRON5', 'CINCINNATI5', 'CLEVELAND5', 'DAYTON5', 'BROKEN ARROW',
#        'NORMAN', 'OKLAHOMA CITY', 'TULSA', 'EUGENE', 'GRESHAM',
#        'PORTLAND', 'SALEM5', 'ALLENTOWN6', 'ERIE', 'PHILADELPHIA',
#        'PITTSBURGH', 'PROVIDENCE', 'CHARLESTON', 'NORTH CHARLESTON',
#        'CHATTANOOGA', 'CLARKSVILLE', 'KNOXVILLE', 'MEMPHIS',
#        'MURFREESBORO', 'NASHVILLE', 'ABILENE', 'ARLINGTON', 'AUSTIN',
#        'BEAUMONT', 'BROWNSVILLE', 'CARROLLTON', 'CORPUS CHRISTI',
#        'DALLAS', 'EL PASO', 'GARLAND', 'GRAND PRAIRIE', 'HOUSTON',
#        'IRVING', 'KILLEEN', 'LAREDO', 'LUBBOCK', 'MCALLEN', 'MESQUITE',
#        'MIDLAND', 'ODESSA', 'RICHARDSON', 'ROUND ROCK', 'SAN ANTONIO',
#        'WACO', 'WICHITA FALLS', 'SALT LAKE CITY', 'WEST JORDAN',
#        'WEST VALLEY', 'ALEXANDRIA', 'CHESAPEAKE', 'HAMPTON',
#        'NEWPORT NEWS ', 'NORFOLK', 'VIRGINIA BEACH', 'BELLEVUE',
#        'EVERETT', 'SEATTLE5', 'SPOKANE', 'TACOMA5', 'VANCOUVER5',
#        'GREEN BAY', 'MADISON', 'MILWAUKEE'], dtype=object)

# %%
# fix spellings
raw_data_df["State"].replace({"ARKANSAS5": "ARKANSAS", "COLORADO5": "COLORADO", "FLORIDA5": "FLORIDA", "IDAHO5":"IDAHO", "IOWA5": "IOWA", "KENTUCKY5": "KENTUCKY", "MINNESOTA5":"MINNESOTA", "MONTANA5": "MONTANA", "MISSOURI5": "MISSOURI5", "NEW HAMPSHIRE5":"NEW HAMPSHIRE", "NEW YORK6": "NEW YORK",
       "NORTH DAKOTA5": "NORTH DAKOTA", "PENNSYLVANIA5": "PENNSYLVANIA", "RHODE ISLAND5": "RHODE ISLAND", "SOUTH CAROLINA5": "SOUTH CAROLINA", "TENNESSEE5": "TENNESSEE", "UTAH5": "UTAH", "VIRGINIA5": "VIRGINIA", "WISCONSIN5": "WISCONSIN"}, inplace=True)

raw_data_df["City"].replace({"BIRMINGHAM3": "BIRMINGHAM", "MOBILE3, 4": "MOBILE", "ANCHORAGE5": "ANCHORAGE", "CHANDLER6": "CHANDLER", "GILBERT5":"GILBERT", "PHOENIX7": "PHOENIX", "TUCSON6, 8": "TUSCON", "THORNTON6": "THORNTON", "NEW HAVEN5": "NEW HAVEN", "STAMFORD5": "STAMFORD", "ATHENS-CLARKE COUNTY": "ATHENS-CLARKE", "SAVANNAH-CHATHAM METROPOLITAN": "SAVANNAH-CHATHAM", "CHICAGO9": "CHICAGO", "ROCKFORD5": "ROCKFORD", "FORT WAYNE5": "FORT WAYNE", "INDIANAPOLIS5": "INDIANAPOLIS", "SOUTH BEND5": "SOUTH BEND", "WICHITA5": "WICHITA", "LEXINGTON5":"LEXINGTON", "LOUISVILLE METRO": "LOUISVILLE", "CAMBRIDGE5":"CAMBRIDGE", "LOWELL5":"LOWELL", "SPRINGFIELD5": "SPRINGFIELD", "WORCESTER5": "WORCESTER", "LAS VEGAS METROPOLITAN \n  POLICE DEPARTMENT": "LAS VEGAS", "AKRON5": "AKRON", "CINCINNATI5": "CINCINNATI", "CLEVELAND5": "CLEVELAND", "DAYTON5": "DAYTON", "SALEM5": "SALEM", "ALLENTOWN6": "ALLENTOWN", "TACOMA5": "TACOMA", "VANCOUVER5": "VANCOUVER"}, inplace=True)

# fill in empty state/city values
raw_data_df['State'] = raw_data_df['State'].ffill()
raw_data_df['City'] = raw_data_df['City'].ffill()

raw_data_df
# Out:
#          State        City    Year Population Violent Crime Murder Rape  \
# 0      ALABAMA  BIRMINGHAM  2012.0    213,266           NaN    NaN  NaN
# 1      ALABAMA  BIRMINGHAM  2013.0        NaN         1,468     39   79
# 2      ALABAMA  HUNTSVILLE  2012.0    183,691           813      1   46
# 3      ALABAMA  HUNTSVILLE  2013.0        NaN           793     12   22
# 4      ALABAMA      MOBILE  2012.0    251,516           NaN    NaN  NaN
# ..         ...         ...     ...        ...           ...    ...  ...
# 586  WISCONSIN   MILWAUKEE     NaN        NaN           NaN    NaN  NaN
# 587  WISCONSIN   MILWAUKEE     NaN        NaN           NaN    NaN  NaN
# 588  WISCONSIN   MILWAUKEE     NaN        NaN           NaN    NaN  NaN
# 589  WISCONSIN   MILWAUKEE     NaN        NaN           NaN    NaN  NaN
# 590  WISCONSIN   MILWAUKEE     NaN        NaN           NaN    NaN
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# 0       NaN                NaN            NaN      NaN           NaN
# 1       455                895          6,357    1,942         3,964
# 2       231                535          4,606    1,095         3,136
# 3       208                551          4,347      893         3,149
# 4       NaN                NaN            NaN      NaN           NaN
# ..      ...                ...            ...      ...           ...
# 586     NaN                NaN            NaN      NaN           NaN
# 587     NaN                NaN            NaN      NaN           NaN
# 588     NaN                NaN            NaN      NaN           NaN
# 589     NaN                NaN            NaN                    NaN
# 590     NaN                NaN            NaN      NaN           NaN
#
#     Motor Vehicle Theft  Arson
# 0                   NaN    NaN
# 1                   451    NaN
# 2                   375   10.0
# 3                   305    NaN
# 4                   NaN    NaN
# ..                  ...    ...
# 586                 NaN    NaN
# 587                 NaN    NaN
# 588                 NaN    NaN
# 589                 NaN    NaN
# 590                 NaN    NaN
#
# [591 rows x 14 columns]

# %%
# drop rows with missing values
data_df = raw_data_df.dropna()
data_df
# Out:
#           State        City    Year Population Violent Crime Murder Rape  \
# 2       ALABAMA  HUNTSVILLE  2012.0    183,691           813      1   46
# 6       ALABAMA  MONTGOMERY  2012.0    209,018           315     12   13
# 8        ALASKA   ANCHORAGE  2012.0    299,143         1,217     11  145
# 10      ARIZONA    CHANDLER  2012.0    242,721           315      2   37
# 12      ARIZONA     GILBERT  2012.0    214,264           103      4    9
# ..          ...         ...     ...        ...           ...    ...  ...
# 528  WASHINGTON      TACOMA  2012.0    202,646           765      6   54
# 530  WASHINGTON   VANCOUVER  2012.0    166,375           288      4   44
# 532   WISCONSIN   GREEN BAY  2012.0    106,080           262      2   24
# 534   WISCONSIN     MADISON  2012.0    237,508           454      2   59
# 536   WISCONSIN   MILWAUKEE  2012.0    599,395         3,551     37  105
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# 2       231                535          4,606    1,095         3,136
# 6       150                140          4,461    1,127         2,968
# 8       234                827          4,871      503         4,009
# 10       72                204          3,412      513         2,765
# 12       25                 65          1,707      325         1,286
# ..      ...                ...            ...      ...           ...
# 528     222                483          6,195    1,525         3,708
# 530      79                161          2,986      516         1,998
# 532      42                194          1,475      355         1,062
# 534     117                276          3,639      640         2,866
# 536   1,228              2,181         14,581    2,976         9,637
#
#     Motor Vehicle Theft  Arson
# 2                   375   10.0
# 6                   366   30.0
# 8                   359   47.0
# 10                  134   27.0
# 12                   96   14.0
# ..                  ...    ...
# 528                 962   36.0
# 530                 472   26.0
# 532                  58    9.0
# 534                 133   18.0
# 536               1,968  158.0
#
# [260 rows x 14 columns]

# %%
data_df.dtypes
# Out:
# State                   object
# City                    object
# Year                   float64
# Population              object
# Violent Crime           object
# Murder                  object
# Rape                    object
# Robbery                 object
# Aggravated\nassault     object
# Property Crime          object
# Burglary                object
# Larceny Theft           object
# Motor Vehicle Theft     object
# Arson                   object
# dtype: object

# %%
# Convert data types
data_df["Year"] = data_df["Year"].astype(int)
#data_df["Population"] = data_df["Population"].str.replace(',', '').astype(int)
# Out:
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Convert data types
data_df["Year"] = data_df["Year"].astype(int)
data_df["Population"] = data_df["Population"].astype(int)
data_df["Violent Crime"] = data_df["Violent Crime"].astype(int)
data_df["Murder"] = data_df["Murder"].astype(int)
data_df["Rape"] = data_df["Rape"].astype(int)
data_df["Robbery"] = data_df["Robbery"].astype(int)
data_df["Aggravated assault"] = data_df["Aggravated assault"].astype(int)
data_df["Property Crime"] = data_df["Property Crime"].astype(int)
data_df["Burglary"] = data_df["Burglary"].astype(int)
data_df["Larceny Theft"] = data_df["Larceny Theft"].astype(int)
data_df["Motor Vehicle Theft"] = data_df["Motor Vehicle Theft"].astype(int)
data_df["Arson"] = data_df["Arson"].astype(int)
# Out:
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-adfb7da2d21d> in <module>
#       1 # Convert data types
#       2 data_df["Year"] = data_df["Year"].astype(int)
# ----> 3 data_df["Population"] = data_df["Population"].astype(int)
#       4 data_df["Violent Crime"] = data_df["Violent Crime"].astype(int)
#       5 data_df["Murder"] = data_df["Murder"].astype(int)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     872         # work around NumPy brokenness, #1987
#     873         if np.issubdtype(dtype.type, np.integer):
# --> 874             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     875
#     876         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '213,266'

# %%
data_df
# Out:
#           State        City  Year Population Violent Crime Murder Rape  \
# 1       ALABAMA  BIRMINGHAM  2012    213,266         3,237     67  152
# 3       ALABAMA  HUNTSVILLE  2012    183,691         1,696     14   72
# 5       ALABAMA      MOBILE  2012    251,516         1,314     32   45
# 7       ALABAMA  MONTGOMERY  2012    209,018           827     44   41
# 9        ALASKA   ANCHORAGE  2012    299,143         2,479     15  303
# ..          ...         ...   ...        ...           ...    ...  ...
# 547  WASHINGTON     SPOKANE  2012    212,163         1,369     13   81
# 549  WASHINGTON      TACOMA  2012    202,646         1,617     12   91
# 551  WASHINGTON   VANCOUVER  2012    166,375           581      5   70
# 553   WISCONSIN   GREEN BAY  2012    106,080           514      1   44
# 557   WISCONSIN   MILWAUKEE  2012    599,395         7,759     91  230
#
#     Robbery Aggravated\nassault Property Crime Burglary Larceny Theft  \
# 1       983               2,035         14,788    4,704         9,042
# 3       456               1,154          9,261    2,165         6,386
# 5       460                 777         12,103    2,796         8,755
# 7       459                 283         12,058    3,409         7,548
# 9       488               1,673         10,543    1,158         8,554
# ..      ...                 ...            ...      ...           ...
# 547     537                 738         18,522    3,827        12,600
# 549     491               1,023         12,889    2,976         8,001
# 551     173                 333          6,481    1,020         4,388
# 553      87                 382          2,978      659         2,210
# 557   3,027               4,411         30,228    6,977        18,448
#
#     Motor Vehicle Theft Arson
# 1                 1,042   117
# 3                   710    20
# 5                   552    66
# 7                 1,101    64
# 9                   831    97
# ..                  ...   ...
# 547               2,095    44
# 549               1,912    71
# 551               1,073    51
# 553                 109    15
# 557               4,803   306
#
# [270 rows x 14 columns]

# %%
# sort by State
cleaned_data_df = data_df.sort_values(by=["State"], inplace=True)
cleaned_data_df
# Out:
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#export cleaned dataframe
cleaned_data_df.to_csv("cleaned_2012.csv", index = False)
cleaned_data_df.to_json("cleaned_2012.json")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-8cf5846e7a96> in <module>
#       1 #export cleaned dataframe
# ----> 2 cleaned_data_df.to_csv("cleaned_2012.csv", index = False)
#       3 cleaned_data_df.to_json("cleaned_2012.json")
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'
