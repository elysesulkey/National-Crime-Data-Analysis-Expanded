# %%
import pandas as pd

# %%
df = pd.read_csv("state_year_avg.csv")
df
# Out:
#           State  Year  Population  Violent Crime  Murder  Rape  Robbery  \
# 0       ALABAMA  2011      200328           1797      33    90      591
# 1        ALASKA  2011      296955           2388      12   283      465
# 2       ARIZONA  2011      361339           1502      19   105      550
# 3      ARKANSAS  2011      194988           2905      37   161      858
# 4    CALIFORNIA  2011      266646           1267      15    56      525
# ..          ...   ...         ...            ...     ...   ...      ...
# 303       TEXAS  2018      279337            661       7    92      157
# 304        UTAH  2018      143286            363       3    71       79
# 305    VIRGINIA  2018      229837            352       8    41       82
# 306  WASHINGTON  2018      151524            332       2    69       74
# 307   WISCONSIN  2018      319785           1646      19   128      398
#
#      Aggravated Assault  Property Crime  Burglary  Larceny Theft  \
# ...

# %%
df.to_json("state_year_avg.json")
