# %%
import pandas as pd
import numpy as np

# %%
# import csv
data11 = "FBI_crime_data_cleaned/cleaned_2011.csv"
data11_df = pd.read_csv(data11)

data12 = "FBI_crime_data_cleaned/cleaned_2012.csv"
data12_df = pd.read_csv(data12)

data13 = "FBI_crime_data_cleaned/cleaned_2013.csv"
data13_df = pd.read_csv(data13)

data14 = "FBI_crime_data_cleaned/cleaned_2014.csv"
data14_df = pd.read_csv(data14)

data15 = "FBI_crime_data_cleaned/cleaned_2015.csv"
data15_df = pd.read_csv(data15)

data16 = "FBI_crime_data_cleaned/cleaned_2016.csv"
data16_df = pd.read_csv(data16)

data17 = "FBI_crime_data_cleaned/cleaned_2017.csv"
data17_df = pd.read_csv(data17)

data18 = "FBI_crime_data_cleaned/cleaned_2018.csv"
data18_df = pd.read_csv(data18)

data19 = "FBI_crime_data_cleaned/cleaned_2019.csv"
data19_df = pd.read_csv(data19)

# %%
joined_data = [data11_df, data12_df, data13_df, data14_df, data15_df, data16_df, data17_df, data18_df, data19_df]
combined_data = pd.concat(joined_data)
combined_data
# Out:
#           State        City  Year  Population  Violent Crime  Murder  Rape  \
# 0       ALABAMA  BIRMINGHAM  2011      213258           3163      54   182
# 1       ALABAMA  HUNTSVILLE  2011      180972           1521      13    51
# 2       ALABAMA  MONTGOMERY  2011      206754            707      31    38
# 3        ALASKA   ANCHORAGE  2011      296955           2388      12   283
# 4       ARIZONA  TEMPE       2011      164008            787       5    45
# ..          ...         ...   ...         ...            ...     ...   ...
# 251  WASHINGTON    BELLEVUE  2018      146913             95       0    14
# 252  WASHINGTON     SPOKANE  2018      218222            814       4   190
# 253   WISCONSIN     MADISON  2018      258455            501       2    57
# 254   WISCONSIN   GREEN BAY  2018      105281            247       1    43
# 255   WISCONSIN   MILWAUKEE  2018      595619           4190      53   284
#
# ...

# %%
new_combined_data = combined_data.drop(columns=["City"], axis=1)

# %%
# sort by State
new_combined_data.sort_values(by=["State", "Year"], inplace=True)
new_combined_data
# Out:
#          State  Year  Population  Violent Crime  Murder  Rape  Robbery  \
# 0      ALABAMA  2011      213258           3163      54   182     1011
# 1      ALABAMA  2011      180972           1521      13    51      408
# 2      ALABAMA  2011      206754            707      31    38      354
# 0      ALABAMA  2012      213266           3237      67   152      983
# 1      ALABAMA  2012      183691           1696      14    72      456
# ..         ...   ...         ...            ...     ...   ...      ...
# 260  WISCONSIN  2017      105331            211       0    39       25
# 261  WISCONSIN  2017      255850            477       7    39      110
# 253  WISCONSIN  2018      258455            501       2    57       90
# 254  WISCONSIN  2018      105281            247       1    43       25
# 255  WISCONSIN  2018      595619           4190      53   284     1080
#
#      Aggravated Assault  Property Crime  Burglary  Larceny Theft  \
# ...

# %%
new_combined_data.reset_index(drop=True, inplace=True)
new_combined_data
# Out:
#           State  Year  Population  Violent Crime  Murder  Rape  Robbery  \
# 0       ALABAMA  2011      213258           3163      54   182     1011
# 1       ALABAMA  2011      180972           1521      13    51      408
# 2       ALABAMA  2011      206754            707      31    38      354
# 3       ALABAMA  2012      213266           3237      67   152      983
# 4       ALABAMA  2012      183691           1696      14    72      456
# ...         ...   ...         ...            ...     ...   ...      ...
# 2013  WISCONSIN  2017      105331            211       0    39       25
# 2014  WISCONSIN  2017      255850            477       7    39      110
# 2015  WISCONSIN  2018      258455            501       2    57       90
# 2016  WISCONSIN  2018      105281            247       1    43       25
# 2017  WISCONSIN  2018      595619           4190      53   284     1080
#
#       Aggravated Assault  Property Crime  Burglary  Larceny Theft  \
# ...

# %%
#export cleaned dataframe
new_combined_data.to_csv("FBI_crime_data_cleaned/combined_data.csv", index = False)
new_combined_data.to_json("FBI_crime_data_cleaned/combined_data.json")
