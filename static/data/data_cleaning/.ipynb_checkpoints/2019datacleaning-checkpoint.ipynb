# %%
import pandas as pd
import numpy as np

# %%
# import csv
raw_data2019 = "FBI_crime_data_raw/2019.csv"
raw_data2019_df = pd.read_csv(raw_data2019)

raw_data2019_df.columns
# Out:
# Index(['State', 'City', 'Unnamed: 2', 'Population1', 'Violent \ncrime',
#        'Murder', 'Rape2', 'Robbery', 'Aggravated \nassault',
#        'Property \ncrime', 'Burglary', 'Larceny-\ntheft',
#        'Motor \nvehicle \ntheft', 'Arson3'],
#       dtype='object')

# %%
raw_data2019_df = raw_data2019_df.rename(columns={"Unnamed: 2": "Year", "Population1":"Population", "Violent \ncrime":"Violent Crime", "Rape2":"Rape", "Aggravated \nassault":"Aggravated Assault", "Property \ncrime":"Property Crime", "Larceny-\ntheft":"Larceny Theft", "Motor \nvehicle \ntheft":"Motor Vehicle Theft", "Arson3":"Arson"})
raw_data2019_df
# Out:
#        State         City  Year Population Violent Crime  Murder  Rape  \
# 0    ALABAMA  HUNTSVILLE4  2018   196,620            NaN     NaN   NaN
# 1        NaN          NaN  2019        NaN          872     12.0   79
# 2        NaN   TUSCALOOSA  2018   101,764           253      3.0   20
# 3        NaN          NaN  2019        NaN          311      4.0   18
# 4    ARIZONA     CHANDLER  2018   255,986           287      1.0   74
# ..       ...          ...   ...        ...           ...     ...   ...
# 547      NaN          NaN  2019        NaN          242      2.0   35
# 548      NaN      MADISON  2018   258,455           501      2.0   57
# 549      NaN          NaN  2019        NaN          434      0.0   49
# 550      NaN    MILWAUKEE  2018   595,619         4,190     53.0  284
# 551      NaN          NaN  2019        NaN        3,429     44.0  169
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
raw_data2019_df = raw_data2019_df.drop(columns=["Unnamed: 14"])
raw_data2019_df
# Out:
#          State        City  Year Population Violent Crime  Murder Rape  \
# 0      ALABAMA  BIRMINGHAM  2017    212,178         1,833    42.0   92
# 1          NaN         NaN  2018        NaN         1,978    47.0   86
# 2          NaN     MOBILE4  2017    248,431           937    22.0   57
# 3          NaN         NaN  2018        NaN           820    15.0   73
# 4          NaN  MONTGOMERY  2017    199,099           656    19.0   35
# ..         ...         ...   ...        ...           ...     ...  ...
# 551        NaN         NaN  2018        NaN           402     2.0   87
# 552  WISCONSIN   GREEN BAY  2017    105,331           211     0.0   39
# 553        NaN         NaN  2018        NaN           243     1.0   40
# 554        NaN     MADISON  2017    255,850           477     7.0   39
# 555        NaN         NaN  2018        NaN           516     3.0   55
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
# replace empty strings with NaN
raw_data2019_df['State'] = raw_data2019_df['State'].replace(' ', np.nan).ffill()
raw_data2019_df['City'] = raw_data2019_df['City'].replace(' ', np.nan).ffill()

# %%
# list of values of State column
States = raw_data2019_df['State'].unique()
States
# Out:
# array(['ALABAMA', 'ARIZONA', 'ARKANSAS', 'CALIFORNIA', 'COLORADO',
#        'CONNECTICUT', 'FLORIDA', 'GEORGIA', 'HAWAII', 'IDAHO', 'ILLINOIS',
#        'INDIANA', 'KANSAS', 'KENTUCKY', 'LOUISIANA', 'MARYLAND',
#        'MASSACHUSETTS', 'MICHIGAN', 'MINNESOTA', 'MISSISSIPPI',
#        'MISSOURI', 'MONTANA', 'NEBRASKA', 'NEVADA', 'NEW HAMPSHIRE',
#        'NEW JERSEY', 'NEW MEXICO', 'NEW YORK', 'NORTH CAROLINA 5, 6, 8',
#        'NORTH DAKOTA', 'OHIO', 'OKLAHOMA', 'OREGON', 'PENNSYLVANIA',
#        'RHODE ISLAND', 'SOUTH CAROLINA', 'SOUTH DAKOTA', 'TENNESSEE',
#        'TEXAS', 'UTAH', 'VIRGINIA', 'WASHINGTON', 'WISCONSIN'],
#       dtype=object)

# %%
# list of values of city column
Cities = raw_data2019_df['City'].unique()
Cities
# Out:
# array(['HUNTSVILLE4', 'TUSCALOOSA', 'CHANDLER', 'GILBERT', 'GLENDALE',
#        'MESA', 'PEORIA', 'PHOENIX', 'SCOTTSDALE', 'SURPRISE', 'TEMPE',
#        'TUCSON', 'LITTLE ROCK', 'ANAHEIM', 'ANTIOCH', 'BAKERSFIELD',
#        'BERKELEY', 'BURBANK', 'CARLSBAD', 'CHULA VISTA', 'CLOVIS',
#        'CONCORD', 'CORONA', 'COSTA MESA', 'DALY CITY', 'DOWNEY',
#        'EL CAJON', 'EL MONTE', 'ELK GROVE', 'ESCONDIDO', 'FAIRFIELD',
#        'FONTANA', 'FREMONT', 'FRESNO', 'FULLERTON', 'GARDEN GROVE',
#        'HAYWARD', 'HUNTINGTON BEACH', 'INGLEWOOD', 'IRVINE',
#        'JURUPA VALLEY', 'LANCASTER', 'LONG BEACH', 'LOS ANGELES',
#        'MODESTO', 'MORENO VALLEY', 'MURRIETA', 'NORWALK', 'OAKLAND',
#        'OCEANSIDE', 'ONTARIO', 'ORANGE', 'OXNARD', 'PALMDALE', 'PASADENA',
#        'POMONA', 'RIALTO', 'RICHMOND', 'RIVERSIDE', 'ROSEVILLE',
#        'SACRAMENTO', 'SALINAS', 'SAN BERNARDINO', 'SAN DIEGO',
#        'SAN FRANCISCO', 'SAN JOSE', 'SAN MATEO', 'SANTA CLARA',
# ...

# %%
# fix spellings
raw_data2019_df["State"].replace({"NORTH CAROLINA 5, 6, 8": "NORTH CAROLINA"}, inplace=True)

raw_data2019_df["City"].replace({"HUNTSVILLE4": "HUNTSVILLE", "SAVANNAH-CHATHAM METROPOLITAN": "SAVANNAH-CHATHAM", "NAPERVILLE5": "NAPERVILLE", "NEW ORLEANS5": "NEW ORLEANS", "BALTIMORE5":"BALTIMORE", "MINNEAPOLIS6": "MINNEAPOLIS", "ROCHESTER6": "ROCHESTER", "JACKSON7": "JACKSON", "INDEPENDENCE6": "INDEPENDENCE", "LAS VEGAS METROPOLITAN POLICE DEPARTMENT": "LAS VEGAS", "FAYETTEVILLE5":"FAYETTEVILLE", "HIGH POINT5": "HIGH POINT", "CINCINNATI5": "CINCINNATI", "COLUMBUS5": "COLUMBUS", "TOLEDO5, 9": "TOLEDO", "OKLAHOMA CITY6": "OKLAHOMA CITY", "PORTLAND10": "PORTLAND", "METROPOLITAN NASHVILLE POLICE DEPARTMENT": "NASHVILLE", "AUSTIN6": "AUSTIN", "CORPUS CHRISTI6": "CORPUS CHRISTI", "HOUSTON5": "HOUSTON", "LAREDO6": "LAREDO", "PASADENA6": "PASADENA", "RICHARDSON6": "RICHARDSON"}, inplace=True)

# fill in empty state/city values
raw_data2019_df['State'] = raw_data2019_df['State'].ffill()
raw_data2019_df['City'] = raw_data2019_df['City'].ffill()

raw_data2019_df
# Out:
#          State        City  Year Population Violent Crime  Murder  Rape  \
# 0      ALABAMA  HUNTSVILLE  2018   196,620            NaN     NaN   NaN
# 1      ALABAMA  HUNTSVILLE  2019        NaN          872     12.0   79
# 2      ALABAMA  TUSCALOOSA  2018   101,764           253      3.0   20
# 3      ALABAMA  TUSCALOOSA  2019        NaN          311      4.0   18
# 4      ARIZONA    CHANDLER  2018   255,986           287      1.0   74
# ..         ...         ...   ...        ...           ...     ...   ...
# 547  WISCONSIN   GREEN BAY  2019        NaN          242      2.0   35
# 548  WISCONSIN     MADISON  2018   258,455           501      2.0   57
# 549  WISCONSIN     MADISON  2019        NaN          434      0.0   49
# 550  WISCONSIN   MILWAUKEE  2018   595,619         4,190     53.0  284
# 551  WISCONSIN   MILWAUKEE  2019        NaN        3,429     44.0  169
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
# drop rows with missing values
data2019_df = raw_data2019_df.dropna()
data2019_df
# Out:
#           State       City  Year Population Violent Crime  Murder  Rape  \
# 4       ARIZONA   CHANDLER  2018   255,986           287      1.0   74
# 6       ARIZONA    GILBERT  2018   247,463           132      1.0   49
# 8       ARIZONA   GLENDALE  2018   249,799           594      7.0   69
# 10      ARIZONA       MESA  2018   504,873           967     10.0  143
# 12      ARIZONA     PEORIA  2018   170,177           201      2.0   33
# ..          ...        ...   ...        ...           ...     ...   ...
# 542  WASHINGTON       KENT  2018   129,870           238      4.0   47
# 544  WASHINGTON    SPOKANE  2018   218,222           814      4.0  190
# 546   WISCONSIN  GREEN BAY  2018   105,281           247      1.0   43
# 548   WISCONSIN    MADISON  2018   258,455           501      2.0   57
# 550   WISCONSIN  MILWAUKEE  2018   595,619         4,190     53.0  284
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
data2019_df.dtypes
# Out:
# State                   object
# City                    object
# Year                     int64
# Population              object
# Violent Crime           object
# Murder                 float64
# Rape                    object
# Robbery                 object
# Aggravated Assault      object
# Property Crime          object
# Burglary                object
# Larceny Theft           object
# Motor Vehicle Theft     object
# Arson                  float64
# dtype: object

# %%
# Convert data types
data2019_df["Year"] = data2019_df["Year"].astype(int)
data2019_df["Population"] = data2019_df["Population"].str.replace(',', '').astype(int)
data2019_df["Violent Crime"] = data2019_df["Violent Crime"].str.replace(',', '').astype(int)
data2019_df["Murder"] = data2019_df["Murder"].astype(int)
data2019_df["Rape"] = data2019_df["Rape"].str.replace(',', '').astype(int)
data2019_df["Robbery"] = data2019_df["Robbery"].str.replace(',', '').astype(int)
data2019_df["Aggravated Assault"] = data2019_df["Aggravated Assault"].str.replace(',', '').astype(int)
data2019_df["Property Crime"] = data2019_df["Property Crime"].str.replace(',', '').astype(int)
data2019_df["Burglary"] = data2019_df["Burglary"].str.replace(',', '').astype(int)
data2019_df["Larceny Theft"] = data2019_df["Larceny Theft"].str.replace(',', '').astype(int)
data2019_df["Motor Vehicle Theft"] = data2019_df["Motor Vehicle Theft"].str.replace(',', '').astype(int)
data2019_df["Arson"] = data2019_df["Arson"].astype(int)
# Out:
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
data2019_df
# Out:
#           State       City  Year  Population  Violent Crime  Murder  Rape  \
# 4       ARIZONA   CHANDLER  2018      255986            287       1    74
# 6       ARIZONA    GILBERT  2018      247463            132       1    49
# 8       ARIZONA   GLENDALE  2018      249799            594       7    69
# 10      ARIZONA       MESA  2018      504873            967      10   143
# 12      ARIZONA     PEORIA  2018      170177            201       2    33
# ..          ...        ...   ...         ...            ...     ...   ...
# 542  WASHINGTON       KENT  2018      129870            238       4    47
# 544  WASHINGTON    SPOKANE  2018      218222            814       4   190
# 546   WISCONSIN  GREEN BAY  2018      105281            247       1    43
# 548   WISCONSIN    MADISON  2018      258455            501       2    57
# 550   WISCONSIN  MILWAUKEE  2018      595619           4190      53   284
#
#      Robbery  Aggravated Assault  Property Crime  Burglary  Larceny Theft  \
# ...

# %%
# sort by State
data2019_df.sort_values(by=["State"], inplace=True)
data2019_df
# Out:
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           State        City  Year  Population  Violent Crime  Murder  Rape  \
# 4       ARIZONA    CHANDLER  2018      255986            287       1    74
# 22      ARIZONA      TUCSON  2018      537392           2027      26   255
# 18      ARIZONA    SURPRISE  2018      136611             67       3    10
# 16      ARIZONA  SCOTTSDALE  2018      254961            211       7    53
# 14      ARIZONA     PHOENIX  2018     1653080           6118      67   566
# ..          ...         ...   ...         ...            ...     ...   ...
# 538  WASHINGTON    BELLEVUE  2018      146913             95       0    14
# ...

# %%
#export cleaned dataframe
data2019_df.to_csv("FBI_crime_data_cleaned/cleaned_2019.csv", index = False)
data2019_df.to_json("FBI_crime_data_cleaned/cleaned_2019.json")
