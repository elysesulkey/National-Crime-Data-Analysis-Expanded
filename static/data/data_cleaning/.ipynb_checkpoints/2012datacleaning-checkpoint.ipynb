# %%
import pandas as pd
import numpy as np

# %%
# import csv
raw_data2012 = "FBI_crime_data_raw/2012.csv"
raw_data2012_df = pd.read_csv(raw_data2012)

raw_data2012_df.columns
# Out:
# Index(['State', 'City', 'Unnamed: 2', 'Population1', 'Violent\ncrime',
#        'Murder', 'Forcible\nrape', 'Robbery', 'Aggravated\nassault',
#        'Property\ncrime', 'Burglary', 'Larceny-\ntheft',
#        'Motor\nvehicle\ntheft', 'Arson2', 'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')

# %%
raw_data2012_df = raw_data2012_df.rename(columns={"Unnamed: 2": "Year", "Population1":"Population", "Violent\ncrime":"Violent Crime", "Forcible\nrape":"Rape", "Aggravated\nassault":"Aggravated Assault", "Property\ncrime":"Property Crime", "Larceny-\ntheft":"Larceny Theft", "Motor\nvehicle\ntheft":"Motor Vehicle Theft", "Arson2":"Arson"})
raw_data2012_df
# Out:
#         State        City    Year Population Violent Crime Murder Rape  \
# 0    ALABAMA3  BIRMINGHAM  2011.0        NaN         3,163     54  182
# 1         NaN         NaN  2012.0    213,266         3,237     67  152
# 2         NaN  HUNTSVILLE  2011.0        NaN         1,518     13   51
# 3         NaN         NaN  2012.0    183,691         1,696     14   72
# 4         NaN     MOBILE4  2011.0        NaN         1,619     30   48
# ..        ...         ...     ...        ...           ...    ...  ...
# 597       NaN         NaN     NaN        NaN           NaN    NaN  NaN
# 598       NaN         NaN     NaN        NaN           NaN    NaN  NaN
# 599       NaN         NaN     NaN        NaN           NaN    NaN  NaN
# 600       NaN         NaN     NaN        NaN           NaN    NaN  NaN
# 601       NaN         NaN     NaN        NaN           NaN    NaN
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
raw_data2012_df = raw_data2012_df.drop(columns=["Unnamed: 14", "Unnamed: 15"])
raw_data2012_df
# Out:
#         State        City    Year Population Violent Crime Murder Rape  \
# 0    ALABAMA3  BIRMINGHAM  2011.0        NaN         3,163     54  182
# 1         NaN         NaN  2012.0    213,266         3,237     67  152
# 2         NaN  HUNTSVILLE  2011.0        NaN         1,518     13   51
# 3         NaN         NaN  2012.0    183,691         1,696     14   72
# 4         NaN     MOBILE4  2011.0        NaN         1,619     30   48
# ..        ...         ...     ...        ...           ...    ...  ...
# 597       NaN         NaN     NaN        NaN           NaN    NaN  NaN
# 598       NaN         NaN     NaN        NaN           NaN    NaN  NaN
# 599       NaN         NaN     NaN        NaN           NaN    NaN  NaN
# 600       NaN         NaN     NaN        NaN           NaN    NaN  NaN
# 601       NaN         NaN     NaN        NaN           NaN    NaN
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
# replace empty strings with NaN
raw_data2012_df['State'] = raw_data2012_df['State'].replace(' ', np.nan).ffill()
raw_data2012_df['City'] = raw_data2012_df['City'].replace(' ', np.nan).ffill()

# %%
# list of values of State column
States = raw_data2012_df['State'].unique()
States
# Out:
# array(['ALABAMA3', 'ALASKA', 'ARIZONA', 'ARKANSAS', 'CALIFORNIA',
#        'COLORADO', 'CONNECTICUT', 'FLORIDA', 'GEORGIA', 'IDAHO',
#        'ILLINOIS', 'INDIANA', 'IOWA', 'KANSAS', 'KENTUCKY', 'LOUISIANA',
#        'MARYLAND', 'MASSACHUSETTS', 'MICHIGAN', 'MINNESOTA',
#        'MISSISSIPPI', 'MISSOURI', 'MONTANA3', 'NEBRASKA', 'NEVADA',
#        'NEW HAMPSHIRE', 'NEW JERSEY', 'NEW MEXICO', 'NEW YORK',
#        'NORTH CAROLINA', 'NORTH DAKOTA', 'OHIO', 'OKLAHOMA', 'OREGON',
#        'PENNSYLVANIA', 'RHODE ISLAND', 'SOUTH CAROLINA', 'SOUTH DAKOTA',
#        'TENNESSEE', 'TEXAS', 'UTAH', 'VIRGINIA', 'WASHINGTON',
#        'WISCONSIN'], dtype=object)

# %%
# list of values of city column
Cities = raw_data2012_df['City'].unique()
Cities
# Out:
# array(['BIRMINGHAM', 'HUNTSVILLE', 'MOBILE4', 'MONTGOMERY', 'ANCHORAGE',
#        'CHANDLER3', 'GLENDALE', 'MESA ', 'PEORIA', 'PHOENIX ',
#        'SCOTTSDALE', 'SURPRISE', 'TEMPE     ', 'TUCSON5', 'LITTLE ROCK',
#        'ANAHEIM', 'ANTIOCH', 'BAKERSFIELD', 'BERKELEY', 'BURBANK',
#        'CARLSBAD', 'CHULA VISTA', 'CONCORD', 'CORONA ', 'COSTA MESA ',
#        'DALY CITY', 'DOWNEY', 'EL CAJON', 'ELK GROVE', 'EL MONTE',
#        'ESCONDIDO ', 'FAIRFIELD', 'FONTANA ', 'FREMONT ', 'FRESNO',
#        'FULLERTON', 'GARDEN GROVE', 'HAYWARD', 'HUNTINGTON BEACH',
#        'INGLEWOOD', 'IRVINE', 'LANCASTER', 'LONG BEACH ', 'LOS ANGELES',
#        'MODESTO ', 'MORENO VALLEY', 'MURRIETA', 'NORWALK ', 'OAKLAND',
#        'OCEANSIDE', 'ONTARIO', 'ORANGE', 'OXNARD ', 'PALMDALE',
#        'PASADENA', 'POMONA', 'RANCHO CUCAMONGA ', 'RIALTO', 'RICHMOND',
#        'RIVERSIDE', 'ROSEVILLE', 'SACRAMENTO', 'SALINAS', 'SAN DIEGO',
#        'SAN FRANCISCO', 'SAN JOSE   ', 'SANTA ANA', 'SANTA CLARA',
# ...

# %%
# fix spellings
raw_data2012_df["State"].replace({"ALABAMA3": "ALABAMA", "MONTANA3": "MONTANA"}, inplace=True)

raw_data2012_df["City"].replace({"MOBILE4": "MOBILE", "CHANDLER3": "CHANDLER", "TUCSON5": "TUSCON", "THORNTON3,6": "THORNTON", "ATHENS-CLARKE COUNTY": "ATHENS-CLARKE", "SAVANNAH-CHATHAM METROPOLITAN": "SAVANNAH-CHATHAM", "CHICAGO7": "CHICAGO", "DAVENPORT3": "DAVENPORT", "KANSAS CITY3": "KANSAS CITY3", "LEXINGTON3":"LEXINGTON", "LOUISVILLE METRO": "LOUISVILLE", "STERLING HEIGHTS3": "STERLING HEIGHTS", "ROCHESTER7": "ROCHESTER", "JACKSON3": "JACKSON", "LAS VEGAS METROPOLITAN \n  POLICE DEPARTMENT": "LAS VEGAS", "NORTH LAS VEGAS3,6": "NORTH LAS VEGAS", "BUFFALO3": "BUFFALO", "CARY3": "CARY3", "GREENSBORO6": "GREENSBORO", "TOLEDO5": "TOLEDO", "PROVIDENCE6": "PROVIDENCE", "MADISON8": "MADISON"}, inplace=True)

# fill in empty state/city values
raw_data2012_df['State'] = raw_data2012_df['State'].ffill()
raw_data2012_df['City'] = raw_data2012_df['City'].ffill()

raw_data2012_df
# Out:
#          State        City    Year Population Violent Crime Murder Rape  \
# 0      ALABAMA  BIRMINGHAM  2011.0        NaN         3,163     54  182
# 1      ALABAMA  BIRMINGHAM  2012.0    213,266         3,237     67  152
# 2      ALABAMA  HUNTSVILLE  2011.0        NaN         1,518     13   51
# 3      ALABAMA  HUNTSVILLE  2012.0    183,691         1,696     14   72
# 4      ALABAMA      MOBILE  2011.0        NaN         1,619     30   48
# ..         ...         ...     ...        ...           ...    ...  ...
# 597  WISCONSIN   MILWAUKEE     NaN        NaN           NaN    NaN  NaN
# 598  WISCONSIN   MILWAUKEE     NaN        NaN           NaN    NaN  NaN
# 599  WISCONSIN   MILWAUKEE     NaN        NaN           NaN    NaN  NaN
# 600  WISCONSIN   MILWAUKEE     NaN        NaN           NaN    NaN  NaN
# 601  WISCONSIN   MILWAUKEE     NaN        NaN           NaN    NaN
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
# drop rows with missing values
data2012_df = raw_data2012_df.dropna()
data2012_df
# Out:
#           State        City    Year Population Violent Crime Murder Rape  \
# 1       ALABAMA  BIRMINGHAM  2012.0    213,266         3,237     67  152
# 3       ALABAMA  HUNTSVILLE  2012.0    183,691         1,696     14   72
# 5       ALABAMA      MOBILE  2012.0    251,516         1,314     32   45
# 7       ALABAMA  MONTGOMERY  2012.0    209,018           827     44   41
# 9        ALASKA   ANCHORAGE  2012.0    299,143         2,479     15  303
# ..          ...         ...     ...        ...           ...    ...  ...
# 547  WASHINGTON     SPOKANE  2012.0    212,163         1,369     13   81
# 549  WASHINGTON      TACOMA  2012.0    202,646         1,617     12   91
# 551  WASHINGTON   VANCOUVER  2012.0    166,375           581      5   70
# 553   WISCONSIN   GREEN BAY  2012.0    106,080           514      1   44
# 557   WISCONSIN   MILWAUKEE  2012.0    599,395         7,759     91  230
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
data2012_df.dtypes
# Out:
# State                   object
# City                    object
# Year                   float64
# Population              object
# Violent Crime           object
# Murder                  object
# Rape                    object
# Robbery                 object
# Aggravated Assault      object
# Property Crime          object
# Burglary                object
# Larceny Theft           object
# Motor Vehicle Theft     object
# Arson                   object
# dtype: object

# %%
# Convert data types
data2012_df["Year"] = data2012_df["Year"].astype(int)
data2012_df["Population"] = data2012_df["Population"].str.replace(',', '').astype(int)
data2012_df["Violent Crime"] = data2012_df["Violent Crime"].str.replace(',', '').astype(int)
data2012_df["Murder"] = data2012_df["Murder"].str.replace(',', '').astype(int)
data2012_df["Rape"] = data2012_df["Rape"].str.replace(',', '').astype(int)
data2012_df["Robbery"] = data2012_df["Robbery"].str.replace(',', '').astype(int)
data2012_df["Aggravated Assault"] = data2012_df["Aggravated Assault"].str.replace(',', '').astype(int)
data2012_df["Property Crime"] = data2012_df["Property Crime"].str.replace(',', '').astype(int)
data2012_df["Burglary"] = data2012_df["Burglary"].str.replace(',', '').astype(int)
data2012_df["Larceny Theft"] = data2012_df["Larceny Theft"].str.replace(',', '').astype(int)
data2012_df["Motor Vehicle Theft"] = data2012_df["Motor Vehicle Theft"].str.replace(',', '').astype(int)
data2012_df["Arson"] = data2012_df["Arson"].str.replace(',', '').astype(int)
# Out:
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
data2012_df
# Out:
#           State        City  Year  Population  Violent Crime  Murder  Rape  \
# 1       ALABAMA  BIRMINGHAM  2012      213266           3237      67   152
# 3       ALABAMA  HUNTSVILLE  2012      183691           1696      14    72
# 5       ALABAMA      MOBILE  2012      251516           1314      32    45
# 7       ALABAMA  MONTGOMERY  2012      209018            827      44    41
# 9        ALASKA   ANCHORAGE  2012      299143           2479      15   303
# ..          ...         ...   ...         ...            ...     ...   ...
# 547  WASHINGTON     SPOKANE  2012      212163           1369      13    81
# 549  WASHINGTON      TACOMA  2012      202646           1617      12    91
# 551  WASHINGTON   VANCOUVER  2012      166375            581       5    70
# 553   WISCONSIN   GREEN BAY  2012      106080            514       1    44
# 557   WISCONSIN   MILWAUKEE  2012      599395           7759      91   230
#
# ...

# %%
# sort by State
data2012_df.sort_values(by=["State"], inplace=True)
data2012_df
# Out:
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           State        City  Year  Population  Violent Crime  Murder  Rape  \
# 1       ALABAMA  BIRMINGHAM  2012      213266           3237      67   152
# 3       ALABAMA  HUNTSVILLE  2012      183691           1696      14    72
# 5       ALABAMA      MOBILE  2012      251516           1314      32    45
# 7       ALABAMA  MONTGOMERY  2012      209018            827      44    41
# 9        ALASKA   ANCHORAGE  2012      299143           2479      15   303
# ..          ...         ...   ...         ...            ...     ...   ...
# 539  WASHINGTON    BELLEVUE  2012      126022            161       2    26
# ...

# %%
#export cleaned dataframe
data2012_df.to_csv("FBI_crime_data_cleaned/cleaned_2012.csv", index = False)
data2012_df.to_json("FBI_crime_data_cleaned/cleaned_2012.json")
