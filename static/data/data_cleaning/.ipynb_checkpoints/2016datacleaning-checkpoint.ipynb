# %%
import pandas as pd
import numpy as np

# %%
# import csv
raw_data2016 = "FBI_crime_data_raw/2016.csv"
raw_data2016_df = pd.read_csv(raw_data2016)

raw_data2016_df.columns
# Out:
# Index(['State', 'City', 'Unnamed: 2', 'Population1', 'Violent\ncrime',
#        'Murder', 'Rape\n(revised\ndefinition)2', 'Rape\n(legacy\ndefinition)3',
#        'Robbery', 'Aggravated\nassault', 'Property\ncrime', 'Burglary',
#        'Larceny-\ntheft', 'Motor\nvehicle\ntheft', 'Arson4'],
#       dtype='object')

# %%
raw_data2016_df = raw_data2016_df.rename(columns={"Unnamed: 2": "Year", "Population1":"Population", "Violent\ncrime":"Violent Crime", "Rape\n(revised\ndefinition)2":"Rape", "Rape\n(legacy\ndefinition)3": "Rape2", "Aggravated\nassault":"Aggravated Assault", "Property\ncrime":"Property Crime", "Larceny-\ntheft":"Larceny Theft", "Motor\nvehicle\ntheft":"Motor Vehicle Theft", "Arson4":"Arson"})
raw_data2016_df
# Out:
#        State        City  Year Population Violent Crime  Murder Rape  Rape2  \
# 0    ALABAMA  HUNTSVILLE  2015    190,106           723       5   65    NaN
# 1        NaN         NaN  2016        NaN           876      10   80    NaN
# 2     ALASKA   ANCHORAGE  2015    301,239         1,615      16  323    NaN
# 3        NaN         NaN  2016        NaN         1,692       9  302    NaN
# 4    ARIZONA    CHANDLER  2015    258,875           206       0   26    NaN
# ..       ...         ...   ...        ...           ...     ...  ...    ...
# 523      NaN         NaN  2016        NaN           141       0  NaN   12.0
# 524      NaN     MADISON  2015    248,833           432       3   57    NaN
# 525      NaN         NaN  2016        NaN           395       6   56    NaN
# 526      NaN   MILWAUKEE  2015    600,400         4,302      73  189    NaN
# 527      NaN         NaN  2016        NaN         4,427      53  248    NaN
#
# ...

# %%
raw_data2016_df = raw_data2016_df.drop(columns=["Rape2"])
raw_data2016_df
# Out:
#        State        City  Year Population Violent Crime  Murder Rape Robbery  \
# 0    ALABAMA  HUNTSVILLE  2015    190,106           723       5   65     173
# 1        NaN         NaN  2016        NaN           876      10   80     213
# 2     ALASKA   ANCHORAGE  2015    301,239         1,615      16  323     271
# 3        NaN         NaN  2016        NaN         1,692       9  302     326
# 4    ARIZONA    CHANDLER  2015    258,875           206       0   26      51
# ..       ...         ...   ...        ...           ...     ...  ...     ...
# 523      NaN         NaN  2016        NaN           141       0  NaN      58
# 524      NaN     MADISON  2015    248,833           432       3   57     106
# 525      NaN         NaN  2016        NaN           395       6   56      99
# 526      NaN   MILWAUKEE  2015    600,400         4,302      73  189   1,674
# 527      NaN         NaN  2016        NaN         4,427      53  248   1,531
#
# ...

# %%
# replace empty strings with NaN
raw_data2016_df['State'] = raw_data2016_df['State'].replace(' ', np.nan).ffill()
raw_data2016_df['City'] = raw_data2016_df['City'].replace(' ', np.nan).ffill()

# %%
# list of values of State column
States = raw_data2016_df['State'].unique()
States
# Out:
# array(['ALABAMA', 'ALASKA', 'ARIZONA', 'ARKANSAS', 'CALIFORNIA',
#        'COLORADO', 'CONNECTICUT', 'FLORIDA', 'GEORGIA', 'HAWAII', 'IDAHO',
#        'ILLINOIS', 'INDIANA', 'KANSAS', 'KENTUCKY', 'LOUISIANA',
#        'MARYLAND', 'MASSACHUSETTS', 'MICHIGAN', 'MINNESOTA',
#        'MISSISSIPPI', 'MISSOURI', 'MONTANA', 'NEBRASKA', 'NEVADA',
#        'NEW HAMPSHIRE', 'NEW JERSEY', 'NEW MEXICO', 'NEW YORK',
#        'NORTH CAROLINA', 'NORTH DAKOTA', 'OHIO', 'OKLAHOMA', 'OREGON',
#        'PENNSYLVANIA', 'SOUTH CAROLINA', 'SOUTH DAKOTA', 'TENNESSEE',
#        'TEXAS', 'UTAH', 'VIRGINIA', 'WASHINGTON', 'WISCONSIN'],
#       dtype=object)

# %%
# list of values of city column
Cities = raw_data2016_df['City'].unique()
Cities
# Out:
# array(['HUNTSVILLE', 'ANCHORAGE', 'CHANDLER', 'GILBERT', 'MESA', 'PEORIA',
#        'SCOTTSDALE', 'TEMPE', 'TUCSON', 'LITTLE ROCK', 'ANAHEIM',
#        'ANTIOCH', 'BAKERSFIELD', 'BERKELEY', 'BURBANK', 'CARLSBAD',
#        'CHULA VISTA', 'CLOVIS', 'CONCORD', 'CORONA', 'COSTA MESA',
#        'DALY CITY', 'DOWNEY', 'EL CAJON', 'ELK GROVE', 'EL MONTE',
#        'ESCONDIDO', 'FAIRFIELD', 'FONTANA', 'FREMONT', 'FRESNO',
#        'GARDEN GROVE', 'GLENDALE', 'HAYWARD', 'HUNTINGTON BEACH',
#        'INGLEWOOD', 'IRVINE', 'LANCASTER', 'LONG BEACH', 'LOS ANGELES',
#        'MODESTO', 'MORENO VALLEY', 'MURRIETA', 'NORWALK', 'OAKLAND',
#        'OCEANSIDE', 'ONTARIO', 'ORANGE', 'OXNARD', 'PALMDALE', 'PASADENA',
#        'POMONA', 'RANCHO CUCAMONGA', 'RIALTO', 'RICHMOND', 'RIVERSIDE',
#        'SACRAMENTO', 'SALINAS', 'SAN BERNARDINO', 'SAN DIEGO',
#        'SAN FRANCISCO', 'SAN JOSE', 'SAN MATEO', 'SANTA ANA',
#        'SANTA CLARA', 'SANTA CLARITA', 'SANTA MARIA', 'SANTA ROSA',
# ...

# %%
# fix spellings
#raw_data2015_df["State"].replace({"OHIO9": "OHIO"}, inplace=True)

raw_data2016_df["City"].replace({"WATERBURY6": "WATERBURY", "ORLANDO7": "ORLANDO", "ATHENS-CLARKE COUNTY": "ATHENS-CLARKE", "SAVANNAH-CHATHAM METROPOLITAN": "SAVANNAH-CHATHAM", "EVANSVILLE8": "EVANSVILLE", "LOUISVILLE METRO9": "LOUISVILLE", "OMAHA10":"OMAHA", "LAS VEGAS METROPOLITAN POLICE DEPARTMENT": "LAS VEGAS", "CARROLLTON11":"CARROLLTON", "EVERETT6": "EVERETT"}, inplace=True)

# fill in empty state/city values
raw_data2016_df['State'] = raw_data2016_df['State'].ffill()
raw_data2016_df['City'] = raw_data2016_df['City'].ffill()

raw_data2016_df
# Out:
#          State        City  Year Population Violent Crime  Murder Rape  \
# 0      ALABAMA  HUNTSVILLE  2015    190,106           723       5   65
# 1      ALABAMA  HUNTSVILLE  2016        NaN           876      10   80
# 2       ALASKA   ANCHORAGE  2015    301,239         1,615      16  323
# 3       ALASKA   ANCHORAGE  2016        NaN         1,692       9  302
# 4      ARIZONA    CHANDLER  2015    258,875           206       0   26
# ..         ...         ...   ...        ...           ...     ...  ...
# 523  WISCONSIN     KENOSHA  2016        NaN           141       0  NaN
# 524  WISCONSIN     MADISON  2015    248,833           432       3   57
# 525  WISCONSIN     MADISON  2016        NaN           395       6   56
# 526  WISCONSIN   MILWAUKEE  2015    600,400         4,302      73  189
# 527  WISCONSIN   MILWAUKEE  2016        NaN         4,427      53  248
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
# drop rows with missing values
data2016_df = raw_data2016_df.dropna()
data2016_df
# Out:
#           State       City  Year Population Violent Crime  Murder Rape  \
# 2        ALASKA  ANCHORAGE  2015    301,239         1,615      16  323
# 4       ARIZONA   CHANDLER  2015    258,875           206       0   26
# 6       ARIZONA    GILBERT  2015    247,324            95       2   14
# 8       ARIZONA       MESA  2015    471,034         1,019       6  142
# 10      ARIZONA     PEORIA  2015    170,222           145       1   16
# ..          ...        ...   ...        ...           ...     ...  ...
# 516  WASHINGTON     TACOMA  2015    206,884           760       4   67
# 518  WASHINGTON  VANCOUVER  2015    171,076           356       1   60
# 520   WISCONSIN  GREEN BAY  2015    105,119           216       1   27
# 524   WISCONSIN    MADISON  2015    248,833           432       3   57
# 526   WISCONSIN  MILWAUKEE  2015    600,400         4,302      73  189
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
data2016_df.dtypes
# Out:
# State                   object
# City                    object
# Year                     int64
# Population              object
# Violent Crime           object
# Murder                   int64
# Rape                    object
# Robbery                 object
# Aggravated Assault      object
# Property Crime          object
# Burglary                object
# Larceny Theft           object
# Motor Vehicle Theft     object
# Arson                  float64
# dtype: object

# %%
# Convert data types
data2016_df["Year"] = data2016_df["Year"].astype(int)
data2016_df["Population"] = data2016_df["Population"].str.replace(',', '').astype(int)
data2016_df["Violent Crime"] = data2016_df["Violent Crime"].str.replace(',', '').astype(int)
data2016_df["Murder"] = data2016_df["Murder"].astype(int)
data2016_df["Rape"] = data2016_df["Rape"].str.replace(',', '').astype(int)
data2016_df["Robbery"] = data2016_df["Robbery"].str.replace(',', '').astype(int)
data2016_df["Aggravated Assault"] = data2016_df["Aggravated Assault"].str.replace(',', '').astype(int)
data2016_df["Property Crime"] = data2016_df["Property Crime"].str.replace(',', '').astype(int)
data2016_df["Burglary"] = data2016_df["Burglary"].str.replace(',', '').astype(int)
data2016_df["Larceny Theft"] = data2016_df["Larceny Theft"].str.replace(',', '').astype(int)
data2016_df["Motor Vehicle Theft"] = data2016_df["Motor Vehicle Theft"].str.replace(',', '').astype(int)
data2016_df["Arson"] = data2016_df["Arson"].astype(int)
# Out:
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
data2016_df
# Out:
#           State       City  Year  Population  Violent Crime  Murder  Rape  \
# 2        ALASKA  ANCHORAGE  2015      301239           1615      16   323
# 4       ARIZONA   CHANDLER  2015      258875            206       0    26
# 6       ARIZONA    GILBERT  2015      247324             95       2    14
# 8       ARIZONA       MESA  2015      471034           1019       6   142
# 10      ARIZONA     PEORIA  2015      170222            145       1    16
# ..          ...        ...   ...         ...            ...     ...   ...
# 516  WASHINGTON     TACOMA  2015      206884            760       4    67
# 518  WASHINGTON  VANCOUVER  2015      171076            356       1    60
# 520   WISCONSIN  GREEN BAY  2015      105119            216       1    27
# 524   WISCONSIN    MADISON  2015      248833            432       3    57
# 526   WISCONSIN  MILWAUKEE  2015      600400           4302      73   189
#
#      Robbery  Aggravated Assault  Property Crime  Burglary  Larceny Theft  \
# ...

# %%
# sort by State
data2016_df.sort_values(by=["State"], inplace=True)
data2016_df
# Out:
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           State       City  Year  Population  Violent Crime  Murder  Rape  \
# 2        ALASKA  ANCHORAGE  2015      301239           1615      16   323
# 4       ARIZONA   CHANDLER  2015      258875            206       0    26
# 6       ARIZONA    GILBERT  2015      247324             95       2    14
# 8       ARIZONA       MESA  2015      471034           1019       6   142
# 10      ARIZONA     PEORIA  2015      170222            145       1    16
# ..          ...        ...   ...         ...            ...     ...   ...
# 508  WASHINGTON       KENT  2015      127259            156       3    28
# ...

# %%
#export cleaned dataframe
data2016_df.to_csv("FBI_crime_data_cleaned/cleaned_2016.csv", index = False)
data2016_df.to_json("FBI_crime_data_cleaned/cleaned_2016.json")
