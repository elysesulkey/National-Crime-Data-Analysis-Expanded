# %%
import pandas as pd
import numpy as np

# %%
# import csv
raw_data2014 = "FBI_crime_data_raw/2014.csv"
raw_data2014_df = pd.read_csv(raw_data2014)

raw_data2014_df.columns
# Out:
# Index(['State', 'City', 'Unnamed: 2', 'Population1', 'Violent\ncrime',
#        'Murder', 'Rape\n (revised\ndefinition)2',
#        'Rape\n (legacy\ndefinition)3', 'Robbery', 'Aggravated\nassault',
#        'Property\ncrime', 'Burglary', 'Larceny-\ntheft',
#        'Motor\nvehicle\ntheft', 'Arson4', 'Unnamed: 15'],
#       dtype='object')

# %%
raw_data2014_df = raw_data2014_df.rename(columns={"Unnamed: 2": "Year", "Population1":"Population", "Violent\ncrime":"Violent Crime", "Rape\n (revised\ndefinition)2":"Rape", "Rape\n (legacy\ndefinition)3": "Rape2", "Aggravated\nassault":"Aggravated Assault", "Property\ncrime":"Property Crime", "Larceny-\ntheft":"Larceny Theft", "Motor\nvehicle\ntheft":"Motor Vehicle Theft", "Arson4":"Arson"})
raw_data2014_df
# Out:
#        State         City    Year Population Violent Crime  Murder Rape  \
# 0    ALABAMA  BIRMINGHAM5  2013.0    212,001         1,378    38.0   79
# 1        NaN          NaN  2014.0        NaN           NaN    19.0   84
# 2        NaN   HUNTSVILLE  2013.0    184,738           763    12.0   41
# 3        NaN          NaN  2014.0        NaN           778    12.0   50
# 4        NaN      MOBILE6  2013.0    250,557           716    11.0   40
# ..       ...          ...     ...        ...           ...     ...  ...
# 453      NaN          NaN     NaN        NaN           NaN     NaN  NaN
# 454      NaN          NaN     NaN        NaN           NaN     NaN  NaN
# 455      NaN          NaN     NaN        NaN           NaN     NaN  NaN
# 456      NaN          NaN     NaN        NaN           NaN     NaN  NaN
# 457      NaN          NaN     NaN        NaN           NaN     NaN
#
#      Rape2 Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
raw_data2014_df = raw_data2014_df.drop(columns=["Rape2", "Unnamed: 15"])
raw_data2014_df
# Out:
#        State         City    Year Population Violent Crime  Murder Rape  \
# 0    ALABAMA  BIRMINGHAM5  2013.0    212,001         1,378    38.0   79
# 1        NaN          NaN  2014.0        NaN           NaN    19.0   84
# 2        NaN   HUNTSVILLE  2013.0    184,738           763    12.0   41
# 3        NaN          NaN  2014.0        NaN           778    12.0   50
# 4        NaN      MOBILE6  2013.0    250,557           716    11.0   40
# ..       ...          ...     ...        ...           ...     ...  ...
# 453      NaN          NaN     NaN        NaN           NaN     NaN  NaN
# 454      NaN          NaN     NaN        NaN           NaN     NaN  NaN
# 455      NaN          NaN     NaN        NaN           NaN     NaN  NaN
# 456      NaN          NaN     NaN        NaN           NaN     NaN  NaN
# 457      NaN          NaN     NaN        NaN           NaN     NaN
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
# replace empty strings with NaN
raw_data2014_df['State'] = raw_data2014_df['State'].replace(' ', np.nan).ffill()
raw_data2014_df['City'] = raw_data2014_df['City'].replace(' ', np.nan).ffill()

# %%
# list of values of State column
States = raw_data2014_df['State'].unique()
States
# Out:
# array(['ALABAMA', 'ALASKA', 'ARIZONA', 'CALIFORNIA', 'COLORADO',
#        'FLORIDA', 'GEORGIA', 'IDAHO', 'ILLINOIS', 'INDIANA', 'IOWA',
#        'KANSAS', 'KENTUCKY', 'LOUISIANA', 'MARYLAND', 'MASSACHUSETTS',
#        'MICHIGAN', 'MINNESOTA', 'MISSISSIPPI', 'MISSOURI', 'MONTANA',
#        'NEBRASKA', 'NEVADA', 'NEW HAMPSHIRE', 'NEW JERSEY', 'NEW YORK',
#        'NORTH CAROLINA', 'NORTH DAKOTA', 'OHIO', 'OKLAHOMA', 'OREGON',
#        'PENNSYLVANIA', 'RHODE ISLAND', 'SOUTH CAROLINA', 'SOUTH DAKOTA',
#        'TENNESSEE', 'TEXAS', 'UTAH', 'VIRGINIA', 'WASHINGTON',
#        'WISCONSIN'], dtype=object)

# %%
# list of values of city column
Cities = raw_data2014_df['City'].unique()
Cities
# Out:
# array(['BIRMINGHAM5', 'HUNTSVILLE', 'MOBILE6', 'MONTGOMERY7', 'ANCHORAGE',
#        'GILBERT', 'ANAHEIM', 'ANTIOCH8', 'BAKERSFIELD', 'BERKELEY',
#        'BURBANK', 'CARLSBAD', 'CHULA VISTA', 'CONCORD', 'CORONA ',
#        'COSTA MESA ', 'DALY CITY', 'DOWNEY', 'EL CAJON', 'ELK GROVE',
#        'EL MONTE', 'ESCONDIDO ', 'FAIRFIELD', 'FONTANA ', 'FREMONT ',
#        'FRESNO', 'FULLERTON', 'GARDEN GROVE', 'GLENDALE', 'HAYWARD',
#        'HUNTINGTON BEACH', 'INGLEWOOD', 'IRVINE', 'LANCASTER',
#        'LONG BEACH ', 'LOS ANGELES', 'MODESTO ', 'MORENO VALLEY',
#        'MURRIETA', 'NORWALK ', 'OAKLAND', 'OCEANSIDE', 'ONTARIO',
#        'ORANGE', 'OXNARD ', 'PALMDALE', 'PASADENA', 'POMONA',
#        'RANCHO CUCAMONGA ', 'RIALTO', 'RICHMOND', 'RIVERSIDE',
#        'ROSEVILLE', 'SACRAMENTO', 'SALINAS', 'SAN BERNARDINO ',
#        'SAN DIEGO', 'SAN FRANCISCO', 'SAN JOSE   ', 'SAN MATEO',
#        'SANTA ANA', 'SANTA CLARA', 'SANTA CLARITA', 'SANTA MARIA',
# ...

# %%
# fix spellings
#raw_data2013_df["State"].replace({"ARKANSAS5": "ARKANSAS", "COLORADO5": "COLORADO", "FLORIDA5": "FLORIDA", "IDAHO5":"IDAHO", "IOWA5": "IOWA", "KENTUCKY5": "KENTUCKY", "MINNESOTA5":"MINNESOTA", "MONTANA5": "MONTANA", "MISSOURI5": "MISSOURI5", "NEW HAMPSHIRE5":"NEW HAMPSHIRE", "NEW YORK6": "NEW YORK","NORTH DAKOTA5": "NORTH DAKOTA", "PENNSYLVANIA5": "PENNSYLVANIA", "RHODE ISLAND5": "RHODE ISLAND", "SOUTH CAROLINA5": "SOUTH CAROLINA", "TENNESSEE5": "TENNESSEE", "UTAH5": "UTAH", "VIRGINIA5": "VIRGINIA", "WISCONSIN5": "WISCONSIN"}, inplace=True)

raw_data2014_df["City"].replace({"BIRMINGHAM5": "BIRMINGHAM", "MOBILE6": "MOBILE", "MONTGOMERY7": "MONTGOMERY", "ANTIOCH8": "ANTIOCH", "CENTENNIAL8": "CENTENNIAL", "ATHENS-CLARKE COUNTY": "ATHENS-CLARKE", "SAVANNAH-CHATHAM METROPOLITAN": "SAVANNAH-CHATHAM", "CHICAGO9": "CHICAGO", "ROCKFORD10": "ROCKFORD", "LOUISVILLE METRO": "LOUISVILLE", "DETROIT10":"DETROIT", "LAS VEGAS METROPOLITAN \n  POLICE DEPARTMENT": "LAS VEGAS", "AKRON11": "AKRON", "CINCINNATI11": "CINCINNATI", "CLEVELAND11": "CLEVELAND", "COLUMBUS7, 11": "COLUMBUS", "DAYTON11": "DAYTON", "LUBBOCK8": "LUBBOCK", "MESQUITE8": "MESQUITE", "ROUND ROCK8": "ROUND ROCK", "RICHARDSON8":"RICHARDSON", "SPOKANE8": "SPOKANE"}, inplace=True)

# fill in empty state/city values
raw_data2014_df['State'] = raw_data2014_df['State'].ffill()
raw_data2014_df['City'] = raw_data2014_df['City'].ffill()

raw_data2014_df
# Out:
#          State        City    Year Population Violent Crime  Murder Rape  \
# 0      ALABAMA  BIRMINGHAM  2013.0    212,001         1,378    38.0   79
# 1      ALABAMA  BIRMINGHAM  2014.0        NaN           NaN    19.0   84
# 2      ALABAMA  HUNTSVILLE  2013.0    184,738           763    12.0   41
# 3      ALABAMA  HUNTSVILLE  2014.0        NaN           778    12.0   50
# 4      ALABAMA      MOBILE  2013.0    250,557           716    11.0   40
# ..         ...         ...     ...        ...           ...     ...  ...
# 453  WISCONSIN   MILWAUKEE     NaN        NaN           NaN     NaN  NaN
# 454  WISCONSIN   MILWAUKEE     NaN        NaN           NaN     NaN  NaN
# 455  WISCONSIN   MILWAUKEE     NaN        NaN           NaN     NaN  NaN
# 456  WISCONSIN   MILWAUKEE     NaN        NaN           NaN     NaN  NaN
# 457  WISCONSIN   MILWAUKEE     NaN        NaN           NaN     NaN
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
# drop rows with missing values
data2014_df = raw_data2014_df.dropna()
data2014_df
# Out:
#           State       City    Year Population Violent Crime  Murder Rape  \
# 8        ALASKA  ANCHORAGE  2013.0    299,455         1,200     9.0  199
# 10      ARIZONA    GILBERT  2013.0    225,232           103     1.0    6
# 152    COLORADO     ARVADA  2013.0    110,792            84     0.0   18
# 154    COLORADO     AURORA  2013.0    343,484           712    10.0  116
# 156    COLORADO    BOULDER  2013.0    102,828           116     0.0   23
# ..          ...        ...     ...        ...           ...     ...  ...
# 440  WASHINGTON     TACOMA  2013.0    203,226           920     6.0   84
# 442  WASHINGTON  VANCOUVER  2013.0    166,535           290     2.0   43
# 444   WISCONSIN  GREEN BAY  2013.0    105,107           228     2.0   25
# 448   WISCONSIN    MADISON  2013.0    242,523           400     3.0   32
# 450   WISCONSIN  MILWAUKEE  2013.0    600,805         3,840    37.0  210
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
data2014_df.dtypes
# Out:
# State                   object
# City                    object
# Year                   float64
# Population              object
# Violent Crime           object
# Murder                 float64
# Rape                    object
# Robbery                 object
# Aggravated Assault      object
# Property Crime          object
# Burglary                object
# Larceny Theft           object
# Motor Vehicle Theft     object
# Arson                  float64
# dtype: object

# %%
# Convert data types
data2014_df["Year"] = data2014_df["Year"].astype(int)
data2014_df["Population"] = data2014_df["Population"].str.replace(',', '').astype(int)
data2014_df["Violent Crime"] = data2014_df["Violent Crime"].str.replace(',', '').astype(int)
data2014_df["Murder"] = data2014_df["Murder"].astype(int)
data2014_df["Rape"] = data2014_df["Rape"].str.replace(',', '').astype(int)
data2014_df["Robbery"] = data2014_df["Robbery"].str.replace(',', '').astype(int)
data2014_df["Aggravated Assault"] = data2014_df["Aggravated Assault"].str.replace(',', '').astype(int)
data2014_df["Property Crime"] = data2014_df["Property Crime"].str.replace(',', '').astype(int)
data2014_df["Burglary"] = data2014_df["Burglary"].str.replace(',', '').astype(int)
data2014_df["Larceny Theft"] = data2014_df["Larceny Theft"].str.replace(',', '').astype(int)
data2014_df["Motor Vehicle Theft"] = data2014_df["Motor Vehicle Theft"].str.replace(',', '').astype(int)
data2014_df["Arson"] = data2014_df["Arson"].astype(int)
# Out:
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
data2014_df
# Out:
#           State       City  Year  Population  Violent Crime  Murder  Rape  \
# 8        ALASKA  ANCHORAGE  2013      299455           1200       9   199
# 10      ARIZONA    GILBERT  2013      225232            103       1     6
# 152    COLORADO     ARVADA  2013      110792             84       0    18
# 154    COLORADO     AURORA  2013      343484            712      10   116
# 156    COLORADO    BOULDER  2013      102828            116       0    23
# ..          ...        ...   ...         ...            ...     ...   ...
# 440  WASHINGTON     TACOMA  2013      203226            920       6    84
# 442  WASHINGTON  VANCOUVER  2013      166535            290       2    43
# 444   WISCONSIN  GREEN BAY  2013      105107            228       2    25
# 448   WISCONSIN    MADISON  2013      242523            400       3    32
# 450   WISCONSIN  MILWAUKEE  2013      600805           3840      37   210
#
#      Robbery  Aggravated Assault  Property Crime  Burglary  Larceny Theft  \
# ...

# %%
# sort by State
data2014_df.sort_values(by=["State"], inplace=True)
data2014_df
# Out:
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           State         City  Year  Population  Violent Crime  Murder  Rape  \
# 8        ALASKA    ANCHORAGE  2013      299455           1200       9   199
# 10      ARIZONA      GILBERT  2013      225232            103       1     6
# 172    COLORADO  WESTMINSTER  2013      110093            117       1     9
# 168    COLORADO       PUEBLO  2013      108062            471       1    88
# 166    COLORADO     LAKEWOOD  2013      146298            316       4    58
# ..          ...          ...   ...         ...            ...     ...   ...
# 436  WASHINGTON      SEATTLE  2013      642814           1731       8    72
# ...

# %%
#export cleaned dataframe
data2014_df.to_csv("FBI_crime_data_cleaned/cleaned_2014.csv", index = False)
data2014_df.to_json("FBI_crime_data_cleaned/cleaned_2014.json")
