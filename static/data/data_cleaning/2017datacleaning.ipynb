# %%
import pandas as pd
import numpy as np

# %%
# import csv
raw_data2017 = "FBI_crime_data_raw/2017.csv"
raw_data2017_df = pd.read_csv(raw_data2017)

raw_data2017_df.columns
# Out:
# Index(['State', 'City', 'Unnamed: 2', 'Population1', 'Violent\ncrime',
#        'Murder', 'Rape2', 'Robbery', 'Aggravated\nassault', 'Property\ncrime',
#        'Burglary', 'Larceny-\ntheft', 'Motor\nvehicle\ntheft', 'Arson3',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17'],
#       dtype='object')

# %%
raw_data2017_df = raw_data2017_df.rename(columns={"Unnamed: 2": "Year", "Population1":"Population", "Violent\ncrime":"Violent Crime", "Rape2":"Rape", "Aggravated\nassault":"Aggravated Assault", "Property\ncrime":"Property Crime", "Larceny-\ntheft":"Larceny Theft", "Motor\nvehicle\ntheft":"Motor Vehicle Theft", "Arson3":"Arson"})
raw_data2017_df
# Out:
#        State        City  Year Population Violent Crime  Murder Rape Robbery  \
# 0    ALABAMA  BIRMINGHAM  2016    212,549         1,732      44   75     460
# 1        NaN         NaN  2017        NaN         1,829      42   92     472
# 2        NaN     MOBILE4  2016    249,921           793      18   47     181
# 3        NaN         NaN  2017        NaN           925      20   53     235
# 4        NaN  MONTGOMERY  2016    199,565           563      18   42     187
# ..       ...         ...   ...        ...           ...     ...  ...     ...
# 469      NaN         NaN  2017        NaN           176       4   28      51
# 470      NaN     MADISON  2016    252,136           398       6   59     105
# 471      NaN         NaN  2017        NaN           483      16   37     108
# 472      NaN   MILWAUKEE  2016    600,193         4,485      55  252   1,545
# 473      NaN         NaN  2017        NaN         4,539      55  232   1,334
#
# ...

# %%
raw_data2017_df = raw_data2017_df.drop(columns=["Unnamed: 14", "Unnamed: 15", "Unnamed: 16", "Unnamed: 17"])
raw_data2017_df
# Out:
#        State        City  Year Population Violent Crime  Murder Rape Robbery  \
# 0    ALABAMA  BIRMINGHAM  2016    212,549         1,732      44   75     460
# 1        NaN         NaN  2017        NaN         1,829      42   92     472
# 2        NaN     MOBILE4  2016    249,921           793      18   47     181
# 3        NaN         NaN  2017        NaN           925      20   53     235
# 4        NaN  MONTGOMERY  2016    199,565           563      18   42     187
# ..       ...         ...   ...        ...           ...     ...  ...     ...
# 469      NaN         NaN  2017        NaN           176       4   28      51
# 470      NaN     MADISON  2016    252,136           398       6   59     105
# 471      NaN         NaN  2017        NaN           483      16   37     108
# 472      NaN   MILWAUKEE  2016    600,193         4,485      55  252   1,545
# 473      NaN         NaN  2017        NaN         4,539      55  232   1,334
#
# ...

# %%
# replace empty strings with NaN
raw_data2017_df['State'] = raw_data2017_df['State'].replace(' ', np.nan).ffill()
raw_data2017_df['City'] = raw_data2017_df['City'].replace(' ', np.nan).ffill()

# %%
# list of values of State column
States = raw_data2017_df['State'].unique()
States
# Out:
# array(['ALABAMA', 'ALASKA', 'ARIZONA', 'ARKANSAS', 'CALIFORNIA',
#        'COLORADO', 'CONNECTICUT', 'DISTRICT OF COLUMBIA', 'FLORIDA',
#        'GEORGIA6', 'HAWAII', 'ILLINOIS', 'INDIANA', 'KANSAS', 'KENTUCKY',
#        'LOUISIANA', 'MARYLAND', 'MASSACHUSETTS', 'MICHIGAN', 'MINNESOTA',
#        'MISSISSIPPI', 'MISSOURI', 'MONTANA', 'NEBRASKA', 'NEVADA',
#        'NEW HAMPSHIRE', 'NEW JERSEY', 'NEW MEXICO', 'NEW YORK',
#        'NORTH CAROLINA8', 'NORTH DAKOTA', 'OHIO', 'OKLAHOMA', 'OREGON',
#        'PENNSYLVANIA', 'RHODE ISLAND', 'SOUTH CAROLINA', 'SOUTH DAKOTA',
#        'TENNESSEE', 'UTAH', 'VIRGINIA', 'WASHINGTON', 'WISCONSIN'],
#       dtype=object)

# %%
# list of values of city column
Cities = raw_data2017_df['City'].unique()
Cities
# Out:
# array(['BIRMINGHAM', 'MOBILE4', 'MONTGOMERY', 'ANCHORAGE', 'CHANDLER',
#        'GLENDALE', 'MESA', 'SCOTTSDALE', 'SURPRISE', 'TEMPE',
#        'LITTLE ROCK', 'ANAHEIM', 'ANTIOCH', 'BAKERSFIELD', 'BERKELEY',
#        'BURBANK', 'CARLSBAD', 'CHULA VISTA', 'CLOVIS', 'CONCORD',
#        'CORONA', 'COSTA MESA', 'DALY CITY', 'DOWNEY', 'EL CAJON',
#        'ELK GROVE', 'EL MONTE', 'ESCONDIDO', 'FAIRFIELD', 'FONTANA',
#        'FREMONT', 'FRESNO', 'FULLERTON', 'GARDEN GROVE', 'HAYWARD',
#        'HUNTINGTON BEACH', 'INGLEWOOD', 'IRVINE', 'JURUPA VALLEY',
#        'LANCASTER', 'LONG BEACH', 'LOS ANGELES', 'MODESTO',
#        'MORENO VALLEY', 'MURRIETA', 'NORWALK', 'OAKLAND', 'OCEANSIDE',
#        'ONTARIO', 'ORANGE', 'OXNARD', 'PALMDALE', 'PASADENA', 'POMONA',
#        'RANCHO CUCAMONGA', 'RIALTO', 'RICHMOND', 'RIVERSIDE', 'ROSEVILLE',
#        'SACRAMENTO', 'SALINAS', 'SAN BERNARDINO', 'SAN DIEGO',
#        'SAN FRANCISCO', 'SAN JOSE', 'SAN MATEO', 'SANTA ANA',
# ...

# %%
# fix spellings
raw_data2017_df["State"].replace({"GEORGIA6": "GEORGIA", "NORTH CAROLINA8": "NORTH CAROLINA"}, inplace=True)

raw_data2017_df["City"].replace({"MOBILE4": "MOBILE", "ORLANDO5": "ORLANDO", "ATHENS-CLARKE COUNTY": "ATHENS-CLARKE", "SAVANNAH-CHATHAM METROPOLITAN": "SAVANNAH-CHATHAM", "LOUISVILLE METRO7": "LOUISVILLE", "JACKSON8":"JACKSON", "OMAHA6": "OMAHA", "LAS VEGAS METROPOLITAN POLICE DEPARTMENT": "LAS VEGAS", "LAS CRUCES8":"LAS CRUCES", "TOLEDO9, 10": "TOLEDO", "PROVIDENCE11": "PROVIDENCE", "KENOSHA6": "KENOSHA"}, inplace=True)

# fill in empty state/city values
raw_data2017_df['State'] = raw_data2017_df['State'].ffill()
raw_data2017_df['City'] = raw_data2017_df['City'].ffill()

raw_data2017_df
# Out:
#          State        City  Year Population Violent Crime  Murder Rape  \
# 0      ALABAMA  BIRMINGHAM  2016    212,549         1,732      44   75
# 1      ALABAMA  BIRMINGHAM  2017        NaN         1,829      42   92
# 2      ALABAMA      MOBILE  2016    249,921           793      18   47
# 3      ALABAMA      MOBILE  2017        NaN           925      20   53
# 4      ALABAMA  MONTGOMERY  2016    199,565           563      18   42
# ..         ...         ...   ...        ...           ...     ...  ...
# 469  WISCONSIN     KENOSHA  2017        NaN           176       4   28
# 470  WISCONSIN     MADISON  2016    252,136           398       6   59
# 471  WISCONSIN     MADISON  2017        NaN           483      16   37
# 472  WISCONSIN   MILWAUKEE  2016    600,193         4,485      55  252
# 473  WISCONSIN   MILWAUKEE  2017        NaN         4,539      55  232
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
# drop rows with missing values
data2017_df = raw_data2017_df.dropna()
data2017_df
# Out:
#           State        City  Year Population Violent Crime  Murder Rape  \
# 0       ALABAMA  BIRMINGHAM  2016    212,549         1,732      44   75
# 6        ALASKA   ANCHORAGE  2016    299,097         1,692       9  302
# 8       ARIZONA    CHANDLER  2016    265,922           272       1   61
# 12      ARIZONA        MESA  2016    478,277         1,069      12  146
# 14      ARIZONA  SCOTTSDALE  2016    240,885           197       2   55
# ..          ...         ...   ...        ...           ...     ...  ...
# 462  WASHINGTON      TACOMA  2016    209,914         1,032       5   83
# 464  WASHINGTON   VANCOUVER  2016    174,912           328       0   71
# 466   WISCONSIN   GREEN BAY  2016    105,452           262       1   45
# 470   WISCONSIN     MADISON  2016    252,136           398       6   59
# 472   WISCONSIN   MILWAUKEE  2016    600,193         4,485      55  252
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
data2017_df.dtypes
# Out:
# State                   object
# City                    object
# Year                     int64
# Population              object
# Violent Crime           object
# Murder                   int64
# Rape                    object
# Robbery                 object
# Aggravated Assault      object
# Property Crime          object
# Burglary                object
# Larceny Theft           object
# Motor Vehicle Theft     object
# Arson                  float64
# dtype: object

# %%
# Convert data types
data2017_df["Year"] = data2017_df["Year"].astype(int)
data2017_df["Population"] = data2017_df["Population"].str.replace(',', '').astype(int)
data2017_df["Violent Crime"] = data2017_df["Violent Crime"].str.replace(',', '').astype(int)
data2017_df["Murder"] = data2017_df["Murder"].astype(int)
data2017_df["Rape"] = data2017_df["Rape"].str.replace(',', '').astype(int)
data2017_df["Robbery"] = data2017_df["Robbery"].str.replace(',', '').astype(int)
data2017_df["Aggravated Assault"] = data2017_df["Aggravated Assault"].str.replace(',', '').astype(int)
data2017_df["Property Crime"] = data2017_df["Property Crime"].str.replace(',', '').astype(int)
data2017_df["Burglary"] = data2017_df["Burglary"].str.replace(',', '').astype(int)
data2017_df["Larceny Theft"] = data2017_df["Larceny Theft"].str.replace(',', '').astype(int)
data2017_df["Motor Vehicle Theft"] = data2017_df["Motor Vehicle Theft"].str.replace(',', '').astype(int)
data2017_df["Arson"] = data2017_df["Arson"].astype(int)
# Out:
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
data2017_df
# Out:
#           State        City  Year  Population  Violent Crime  Murder  Rape  \
# 0       ALABAMA  BIRMINGHAM  2016      212549           1732      44    75
# 6        ALASKA   ANCHORAGE  2016      299097           1692       9   302
# 8       ARIZONA    CHANDLER  2016      265922            272       1    61
# 12      ARIZONA        MESA  2016      478277           1069      12   146
# 14      ARIZONA  SCOTTSDALE  2016      240885            197       2    55
# ..          ...         ...   ...         ...            ...     ...   ...
# 462  WASHINGTON      TACOMA  2016      209914           1032       5    83
# 464  WASHINGTON   VANCOUVER  2016      174912            328       0    71
# 466   WISCONSIN   GREEN BAY  2016      105452            262       1    45
# 470   WISCONSIN     MADISON  2016      252136            398       6    59
# 472   WISCONSIN   MILWAUKEE  2016      600193           4485      55   252
#
# ...

# %%
# sort by State
data2017_df.sort_values(by=["State"], inplace=True)
data2017_df
# Out:
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           State        City  Year  Population  Violent Crime  Murder  Rape  \
# 0       ALABAMA  BIRMINGHAM  2016      212549           1732      44    75
# 6        ALASKA   ANCHORAGE  2016      299097           1692       9   302
# 8       ARIZONA    CHANDLER  2016      265922            272       1    61
# 12      ARIZONA        MESA  2016      478277           1069      12   146
# 14      ARIZONA  SCOTTSDALE  2016      240885            197       2    55
# ..          ...         ...   ...         ...            ...     ...   ...
# 460  WASHINGTON     SEATTLE  2016      700313           2078      11   131
# ...

# %%
#export cleaned dataframe
data2017_df.to_csv("FBI_crime_data_cleaned/cleaned_2017.csv", index = False)
