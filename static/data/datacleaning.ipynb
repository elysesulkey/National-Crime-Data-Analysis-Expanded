# %%
import pandas as pd
import numpy as np

# %%
# import csv
raw_data2011 = "FBI_crime_data_raw/2011.csv"
raw_data2011_df = pd.read_csv(raw_data2011)

# drop rows with missing values
#raw_data2012_df2 = raw_data2012_df.dropna(how='any')

raw_data2011_df.columns
# Out:
# Index(['State', 'City', 'Unnamed: 2', 'Population1', 'Violent\ncrime',
#        'Murder', 'Forcible rape', 'Robbery', 'Aggravated assault',
#        'Property\ncrime', 'Burglary', 'Larceny-\ntheft',
#        'Motor\nvehicle\ntheft', 'Arson2', 'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')

# %%
raw_data2011_df = raw_data2011_df.rename(columns={"Unnamed: 2": "Year", "Population1":"Population", "Violent\ncrime":"Violent Crime", "Forcible rape":"Rape", "Aggravated assault":"Aggravated Assault", "Property\ncrime":"Property Crime", "Larceny-\ntheft":"Larceny Theft", "Motor\nvehicle\ntheft":"Motor Vehicle Theft", "Arson2":"Arson"})
raw_data2011_df
# Out:
#         State         City    Year Population Violent Crime Murder Rape  \
# 0    ALABAMA3  BIRMINGHAM4  2010.0        NaN           NaN    NaN  NaN
# 1         NaN          NaN  2011.0    213,258         3,163     54  182
# 2         NaN   HUNTSVILLE  2010.0        NaN         1,182     12   76
# 3         NaN          NaN  2011.0    180,972         1,521     13   51
# 4         NaN      MOBILE5  2010.0        NaN         1,702     25   59
# ..        ...          ...     ...        ...           ...    ...  ...
# 607       NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 608       NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 609       NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 610       NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 611       NaN          NaN     NaN        NaN           NaN    NaN
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
raw_data2011_df = raw_data2011_df.drop(columns=["Unnamed: 14", "Unnamed: 15"])
raw_data2011_df
# Out:
#         State         City    Year Population Violent Crime Murder Rape  \
# 0    ALABAMA3  BIRMINGHAM4  2010.0        NaN           NaN    NaN  NaN
# 1         NaN          NaN  2011.0    213,258         3,163     54  182
# 2         NaN   HUNTSVILLE  2010.0        NaN         1,182     12   76
# 3         NaN          NaN  2011.0    180,972         1,521     13   51
# 4         NaN      MOBILE5  2010.0        NaN         1,702     25   59
# ..        ...          ...     ...        ...           ...    ...  ...
# 607       NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 608       NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 609       NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 610       NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 611       NaN          NaN     NaN        NaN           NaN    NaN
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
# list of values of State column
States = raw_data2011_df['State'].unique()
States
# Out:
# array(['ALABAMA3', nan, 'ALASKA', 'ARIZONA', 'ARKANSAS', 'CALIFORNIA',
#        'COLORADO', 'CONNECTICUT', 'DISTRICT OF COLUMBIA', 'FLORIDA',
#        'GEORGIA', 'IDAHO', 'ILLINOIS', 'INDIANA', 'IOWA', 'KANSAS',
#        'KENTUCKY', 'LOUISIANA', 'MARYLAND', 'MASSACHUSETTS', 'MICHIGAN',
#        'MINNESOTA', 'MISSISSIPPI', 'MISSOURI', 'MONTANA', 'NEBRASKA',
#        'NEVADA', 'NEW HAMPSHIRE', 'NEW JERSEY', 'NEW MEXICO', 'NEW YORK',
#        'NORTH CAROLINA', 'NORTH DAKOTA', 'OHIO', 'OKLAHOMA', 'OREGON',
#        'PENNSYLVANIA', 'SOUTH CAROLINA', 'SOUTH DAKOTA', 'TENNESSEE',
#        'TEXAS', 'UTAH', 'VIRGINIA', 'WASHINGTON', 'WISCONSIN',
#        '1 The 2011 population figures are FBI estimates based on provisional data from the U.S. Census Bureau.  (See Data Declaration.)',
#        '2 The FBI does not publish arson data unless it receives data from either the agency or the state for all 12 months for 2010 and/or 2011.',
# ...

# %%
raw_data2011_df["State"].replace({"ALABAMA3": "ALABAMA", ""}, inplace=True)

# %%
# Convert data types
raw_data2011_df2["Year"] = raw_data2_df["Year"].astype(int)
raw_data2_df["Violent Crime"] = raw_data2_df["Violent Crime"].astype(int)
raw_data2_df["Murder"] = raw_data2_df["Murder"].astype(int)
raw_data2_df["Rape"] = raw_data2_df["Rape"].astype(int)
raw_data2_df["Robbery"] = raw_data2_df["Robbery"].astype(int)
raw_data2_df["Aggravated assault"] = raw_data2_df["Aggravated assault"].astype(int)
raw_data2_df["Property Crime"] = raw_data2_df["Property Crime"].astype(int)
raw_data2_df["Burglary"] = raw_data2_df["Burglary"].astype(int)
raw_data2_df["Larceny Theft"] = raw_data2_df["Larceny Theft"].astype(int)
raw_data2_df["Motor Vehicle Theft"] = raw_data2_df["Motor Vehicle Theft"].astype(int)
raw_data2_df["Arson"] = raw_data2_df["Arson"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d1b1cd12fd03> in <module>
#       1 # Convert data types
# ----> 2 raw_data2011_df2["Year"] = raw_data2_df["Year"].astype(int)
#       3 raw_data2_df["Violent Crime"] = raw_data2_df["Violent Crime"].astype(int)
#       4 raw_data2_df["Murder"] = raw_data2_df["Murder"].astype(int)
#       5 raw_data2_df["Rape"] = raw_data2_df["Rape"].astype(int)
#
# NameError: name 'raw_data2_df' is not defined

# %%
raw_data2_df
# Out:
#          State       City  Year  Population  Violent Crime  Murder  Rape  \
# 4      ARIZONA   CHANDLER  2018      255986            287       1    74
# 5      ARIZONA   CHANDLER  2019      255986            295       2    63
# 6      ARIZONA    GILBERT  2018      247463            132       1    49
# 7      ARIZONA    GILBERT  2019      247463            116       0    27
# 8      ARIZONA   GLENDALE  2018      249799            594       7    69
# ..         ...        ...   ...         ...            ...     ...   ...
# 547  WISCONSIN  GREEN BAY  2019      105281            242       2    35
# 548  WISCONSIN    MADISON  2018      258455            501       2    57
# 549  WISCONSIN    MADISON  2019      258455            434       0    49
# 550  WISCONSIN  MILWAUKEE  2018      595619           4190      53   284
# 551  WISCONSIN  MILWAUKEE  2019      595619           3429      44   169
#
#      Robbery  Aggravated assault  Property Crime  Burglary  Larceny Theft  \
# ...

# %%
# list of values of State column
States = raw_data2_df['State'].unique()
States
# Out:
# array(['ARIZONA', 'ARKANSAS', 'CALIFORNIA', 'COLORADO', 'CONNECTICUT',
#        'FLORIDA', 'GEORGIA', 'HAWAII', 'IDAHO', 'ILLINOIS', 'INDIANA',
#        'KANSAS', 'KENTUCKY', 'LOUISIANA', 'MARYLAND', 'MASSACHUSETTS',
#        'MICHIGAN', 'MINNESOTA', 'MISSOURI', 'MONTANA', 'NEBRASKA',
#        'NEVADA', 'NEW HAMPSHIRE', 'NEW JERSEY', 'NEW MEXICO', 'NEW YORK',
#        'NORTH CAROLINA 5, 6, 8', 'NORTH DAKOTA', 'OHIO', 'OKLAHOMA',
#        'OREGON', 'PENNSYLVANIA', 'RHODE ISLAND', 'SOUTH CAROLINA',
#        'SOUTH DAKOTA', 'TENNESSEE', 'TEXAS', 'UTAH', 'VIRGINIA',
#        'WASHINGTON', 'WISCONSIN'], dtype=object)

# %%
# list of values of City column
Cities = raw_data2_df['City'].unique()
Cities
# Out:
# array(['CHANDLER', 'GILBERT', 'GLENDALE', 'MESA', 'PEORIA', 'PHOENIX',
#        'SCOTTSDALE', 'SURPRISE', 'TEMPE', 'TUCSON', 'LITTLE ROCK',
#        'ANAHEIM', 'ANTIOCH', 'BAKERSFIELD', 'BERKELEY', 'BURBANK',
#        'CARLSBAD', 'CHULA VISTA', 'CLOVIS', 'CONCORD', 'CORONA',
#        'COSTA MESA', 'DALY CITY', 'DOWNEY', 'EL CAJON', 'EL MONTE',
#        'ELK GROVE', 'ESCONDIDO', 'FAIRFIELD', 'FONTANA', 'FREMONT',
#        'FRESNO', 'FULLERTON', 'GARDEN GROVE', 'HAYWARD',
#        'HUNTINGTON BEACH', 'INGLEWOOD', 'IRVINE', 'JURUPA VALLEY',
#        'LANCASTER', 'LONG BEACH', 'LOS ANGELES', 'MODESTO',
#        'MORENO VALLEY', 'MURRIETA', 'NORWALK', 'OAKLAND', 'OCEANSIDE',
#        'ONTARIO', 'ORANGE', 'OXNARD', 'PALMDALE', 'PASADENA', 'POMONA',
#        'RIALTO', 'RICHMOND', 'RIVERSIDE', 'ROSEVILLE', 'SACRAMENTO',
#        'SALINAS', 'SAN BERNARDINO', 'SAN DIEGO', 'SAN FRANCISCO',
#        'SAN JOSE', 'SAN MATEO', 'SANTA CLARA', 'SANTA CLARITA',
# ...

# %%
raw_data2_df["State"].replace({"NORTH CAROLINA 5, 6, 8": "NORTH CAROLINA"}, inplace=True)
raw_data2_df["City"].replace({"BALTIMORE5": "BALTIMORE", "MINNEAPOLIS6": "MINNEAPOLIS", "ROCHESTER6": "ROCHESTER", "INDEPENDENCE6": "INDEPENDENCE", "LAS VEGAS METROPOLITAN POLICE DEPARTMENT": "LAS VEGAS", "FAYETTEVILLE5": "FAYETTEVILLE", "HIGH POINT5": "HIGH POINT", "OKLAHOMA CITY6": "OKLAHOMA CITY", "PORTLAND10": "PORTLAND", "METROPOLITAN NASHVILLE POLICE DEPARTMENT": "NASHVILLE", "AUSTIN6": "AUSTIN", "CORPUS CRISTI6": "CORPUS CRISTI", "LAREDO6": "LAREDO", "PASADENA6": "PASADENA", "RICHARDSON6": "RICHARDSON"}, inplace=True)
# Out:
# /Users/elysesulkey/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
cleaned_data = raw_data2_df.rename(columns = {"Aggravated assault": "Aggravated Assault"})
cleaned_data
# Out:
#          State       City  Year  Population  Violent Crime  Murder  Rape  \
# 4      ARIZONA   CHANDLER  2018      255986            287       1    74
# 5      ARIZONA   CHANDLER  2019      255986            295       2    63
# 6      ARIZONA    GILBERT  2018      247463            132       1    49
# 7      ARIZONA    GILBERT  2019      247463            116       0    27
# 8      ARIZONA   GLENDALE  2018      249799            594       7    69
# ..         ...        ...   ...         ...            ...     ...   ...
# 547  WISCONSIN  GREEN BAY  2019      105281            242       2    35
# 548  WISCONSIN    MADISON  2018      258455            501       2    57
# 549  WISCONSIN    MADISON  2019      258455            434       0    49
# 550  WISCONSIN  MILWAUKEE  2018      595619           4190      53   284
# 551  WISCONSIN  MILWAUKEE  2019      595619           3429      44   169
#
#      Robbery  Aggravated Assault  Property Crime  Burglary  Larceny Theft  \
# ...

# %%
# sort by State
cleaned_data.sort_values(by=["State"], inplace=True)
cleaned_data
# Out:
#          State       City  Year  Population  Violent Crime  Murder  Rape  \
# 4      ARIZONA   CHANDLER  2018      255986            287       1    74
# 23     ARIZONA     TUCSON  2019      537392           1936      27   264
# 21     ARIZONA      TEMPE  2019      188543            430       3    66
# 20     ARIZONA      TEMPE  2018      188543            448       3    75
# 19     ARIZONA   SURPRISE  2019      136611             83       2    15
# ..         ...        ...   ...         ...            ...     ...   ...
# 548  WISCONSIN    MADISON  2018      258455            501       2    57
# 550  WISCONSIN  MILWAUKEE  2018      595619           4190      53   284
# 546  WISCONSIN  GREEN BAY  2018      105281            247       1    43
# 547  WISCONSIN  GREEN BAY  2019      105281            242       2    35
# 551  WISCONSIN  MILWAUKEE  2019      595619           3429      44   169
#
#      Robbery  Aggravated Assault  Property Crime  Burglary  Larceny Theft  \
# ...

# %%
#export cleaned dataframe
cleaned_data.to_csv("cleaned_crime_data.csv", index = False)
cleaned_data.to_json("cleaned_crime_data.json")
