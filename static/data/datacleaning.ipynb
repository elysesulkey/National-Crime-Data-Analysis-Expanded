# %%
import pandas as pd
import numpy as np

# %%
# import csv
raw_data2011 = "FBI_crime_data_raw/2011.csv"
raw_data2011_df = pd.read_csv(raw_data2011)

raw_data2011_df.columns
# Out:
# Index(['State', 'City', 'Unnamed: 2', 'Population1', 'Violent\ncrime',
#        'Murder', 'Forcible rape', 'Robbery', 'Aggravated assault',
#        'Property\ncrime', 'Burglary', 'Larceny-\ntheft',
#        'Motor\nvehicle\ntheft', 'Arson2', 'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')

# %%
raw_data2011_df = raw_data2011_df.rename(columns={"Unnamed: 2": "Year", "Population1":"Population", "Violent\ncrime":"Violent Crime", "Forcible rape":"Rape", "Aggravated assault":"Aggravated Assault", "Property\ncrime":"Property Crime", "Larceny-\ntheft":"Larceny Theft", "Motor\nvehicle\ntheft":"Motor Vehicle Theft", "Arson2":"Arson"})
raw_data2011_df
# Out:
#         State         City    Year Population Violent Crime Murder Rape  \
# 0    ALABAMA3  BIRMINGHAM4  2010.0        NaN           NaN    NaN  NaN
# 1         NaN          NaN  2011.0    213,258         3,163     54  182
# 2         NaN   HUNTSVILLE  2010.0        NaN         1,182     12   76
# 3         NaN          NaN  2011.0    180,972         1,521     13   51
# 4         NaN      MOBILE5  2010.0        NaN         1,702     25   59
# ..        ...          ...     ...        ...           ...    ...  ...
# 600       NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 601       NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 602       NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 603       NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 604       NaN          NaN     NaN        NaN           NaN    NaN
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
raw_data2011_df = raw_data2011_df.drop(columns=["Unnamed: 14", "Unnamed: 15"])
raw_data2011_df
# Out:
#         State         City    Year Population Violent Crime Murder Rape  \
# 0    ALABAMA3  BIRMINGHAM4  2010.0        NaN           NaN    NaN  NaN
# 1         NaN          NaN  2011.0    213,258         3,163     54  182
# 2         NaN   HUNTSVILLE  2010.0        NaN         1,182     12   76
# 3         NaN          NaN  2011.0    180,972         1,521     13   51
# 4         NaN      MOBILE5  2010.0        NaN         1,702     25   59
# ..        ...          ...     ...        ...           ...    ...  ...
# 600       NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 601       NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 602       NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 603       NaN          NaN     NaN        NaN           NaN    NaN  NaN
# 604       NaN          NaN     NaN        NaN           NaN    NaN
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
# replace empty strings with NaN
raw_data2011_df['State'] = raw_data2011_df['State'].replace(' ', np.nan).ffill()
raw_data2011_df['City'] = raw_data2011_df['City'].replace(' ', np.nan).ffill()

# %%
# list of values of State column
States = raw_data2011_df['State'].unique()
States
# Out:
# array(['ALABAMA3', 'ALASKA', 'ARIZONA', 'ARKANSAS', 'CALIFORNIA',
#        'COLORADO', 'CONNECTICUT', 'DISTRICT OF COLUMBIA', 'FLORIDA',
#        'GEORGIA', 'IDAHO', 'ILLINOIS', 'INDIANA', 'IOWA', 'KANSAS',
#        'KENTUCKY', 'LOUISIANA', 'MARYLAND', 'MASSACHUSETTS', 'MICHIGAN',
#        'MINNESOTA', 'MISSISSIPPI', 'MISSOURI', 'MONTANA', 'NEBRASKA',
#        'NEVADA', 'NEW HAMPSHIRE', 'NEW JERSEY', 'NEW MEXICO', 'NEW YORK',
#        'NORTH CAROLINA', 'NORTH DAKOTA', 'OHIO', 'OKLAHOMA', 'OREGON',
#        'PENNSYLVANIA', 'SOUTH CAROLINA', 'SOUTH DAKOTA', 'TENNESSEE',
#        'TEXAS', 'UTAH', 'VIRGINIA', 'WASHINGTON', 'WISCONSIN'],
#       dtype=object)

# %%
# list of values of city column
Cities = raw_data2011_df['City'].unique()
Cities
# Out:
# array(['BIRMINGHAM4', 'HUNTSVILLE', 'MOBILE5', 'MONTGOMERY', 'ANCHORAGE',
#        'CHANDLER    ', 'GILBERT', 'GLENDALE', 'MESA ', 'PEORIA',
#        'PHOENIX ', 'SCOTTSDALE', 'SURPRISE', 'TEMPE     ', 'TUCSON6',
#        'LITTLE ROCK', 'ANAHEIM', 'ANTIOCH', 'BAKERSFIELD', 'BERKELEY',
#        'BURBANK', 'CARLSBAD', 'CHULA VISTA', 'CONCORD', 'CORONA ',
#        'COSTA MESA ', 'DALY CITY', 'DOWNEY', 'EL CAJON', 'ELK GROVE',
#        'EL MONTE', 'ESCONDIDO ', 'FAIRFIELD', 'FONTANA ', 'FREMONT ',
#        'FRESNO', 'FULLERTON', 'GARDEN GROVE', 'HAYWARD',
#        'HUNTINGTON BEACH', 'INGLEWOOD', 'IRVINE', 'LANCASTER',
#        'LONG BEACH ', 'LOS ANGELES', 'MODESTO ', 'MORENO VALLEY',
#        'MURRIETA', 'NORWALK ', 'OAKLAND', 'OCEANSIDE', 'ONTARIO',
#        'ORANGE', 'OXNARD ', 'PALMDALE', 'PASADENA', 'POMONA',
#        'RANCHO CUCAMONGA ', 'RIALTO', 'RICHMOND', 'RIVERSIDE',
#        'ROSEVILLE', 'SACRAMENTO', 'SALINAS', 'SAN BERNARDINO ',
# ...

# %%
# fix spellings
raw_data2011_df["State"].replace({"ALABAMA3": "ALABAMA"}, inplace=True)

raw_data2011_df["City"].replace({"BIRMINGHAM4": "BIRMINGHAM", "MOBILE5": "MOBILE", "TUCSON6": "TUSCON", "THORNTON3,6": "THORNTON", "SAVANNAH-CHATHAM METROPOLITAN": "SAVANNAH-CHATHAM", "CHICAGO7": "CHICAGO", "FORT WAYNE3": "FORT WAYNE", "DAVENPORT3": "DAVENPORT", "KANSAS CITY3": "KANSAS CITY3", "LEXINGTON3":"LEXINGTON", "LOUISVILLE METRO": "LOUISVILLE", "STERLING HEIGHTS3": "STERLING HEIGHTS", "ROCHESTER7": "ROCHESTER","INDEPENDENCE3": "INDEPENDENCE", "BILLINGS3":"BILLINGS", "LAS VEGAS METROPOLITAN \n  POLICE DEPARTMENT": "LAS VEGAS", "BUFFALO3": "BUFFALO", "TOLEDO6": "TOLEDO", "EUGENE3": "EUGENE", "GRESHAM3": "GRESHAM", "PORTLAND3": "PORTLAND", "MIDLAND3": "MIDLAND", "GREEN BAY3": "GREEN BAY", "MADISON3": "MADISON"}, inplace=True)

# fill in empty state/city values
raw_data2011_df['State'] = raw_data2011_df['State'].ffill()
raw_data2011_df['City'] = raw_data2011_df['City'].ffill()

raw_data2011_df
# Out:
#          State        City    Year Population Violent Crime Murder Rape  \
# 0      ALABAMA  BIRMINGHAM  2010.0        NaN           NaN    NaN  NaN
# 1      ALABAMA  BIRMINGHAM  2011.0    213,258         3,163     54  182
# 2      ALABAMA  HUNTSVILLE  2010.0        NaN         1,182     12   76
# 3      ALABAMA  HUNTSVILLE  2011.0    180,972         1,521     13   51
# 4      ALABAMA      MOBILE  2010.0        NaN         1,702     25   59
# ..         ...         ...     ...        ...           ...    ...  ...
# 600  WISCONSIN   MILWAUKEE     NaN        NaN           NaN    NaN  NaN
# 601  WISCONSIN   MILWAUKEE     NaN        NaN           NaN    NaN  NaN
# 602  WISCONSIN   MILWAUKEE     NaN        NaN           NaN    NaN  NaN
# 603  WISCONSIN   MILWAUKEE     NaN        NaN           NaN    NaN  NaN
# 604  WISCONSIN   MILWAUKEE     NaN        NaN           NaN    NaN
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
# drop rows with missing values
data2011_df = raw_data2011_df.dropna()
data2011_df
# Out:
#           State          City    Year Population Violent Crime Murder Rape  \
# 1       ALABAMA    BIRMINGHAM  2011.0    213,258         3,163     54  182
# 3       ALABAMA    HUNTSVILLE  2011.0    180,972         1,521     13   51
# 7       ALABAMA    MONTGOMERY  2011.0    206,754           707     31   38
# 9        ALASKA     ANCHORAGE  2011.0    296,955         2,388     12  283
# 11      ARIZONA  CHANDLER      2011.0    239,466           681      2   62
# ..          ...           ...     ...        ...           ...    ...  ...
# 551  WASHINGTON        TACOMA  2011.0    201,510         1,507     11  125
# 553  WASHINGTON     VANCOUVER  2011.0    164,329           633      9  102
# 555   WISCONSIN     GREEN BAY  2011.0    104,510           371      2   52
# 557   WISCONSIN       MADISON  2011.0    234,225           815      8   74
# 559   WISCONSIN     MILWAUKEE  2011.0    597,426         5,951     85  195
#
# ...

# %%
data2011_df.dtypes
# Out:
# State                   object
# City                    object
# Year                   float64
# Population              object
# Violent Crime           object
# Murder                  object
# Rape                    object
# Robbery                 object
# Aggravated Assault      object
# Property Crime          object
# Burglary                object
# Larceny Theft           object
# Motor Vehicle Theft     object
# Arson                   object
# dtype: object

# %%
# Convert data types
data2011_df["Year"] = data2011_df["Year"].astype(int)
#data2011_df["Population"] = data2011_df["Population"].str.replace(',', '').astype(int)
# Out:
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Convert data types
raw_data2011_df2["Year"] = raw_data2011_df2["Year"].astype(int)
raw_data2011_df2["Population"] = raw_data2011_df2["Population"].astype(int)
raw_data2011_df2["Violent Crime"] = raw_data2011_df2["Violent Crime"].astype(int)
raw_data2011_df2["Murder"] = raw_data2011_df2["Murder"].astype(int)
raw_data2011_df2["Rape"] = raw_data2011_df2["Rape"].astype(int)
raw_data2011_df2["Robbery"] = raw_data2011_df2["Robbery"].astype(int)
raw_data2011_df2["Aggravated assault"] = raw_data2011_df2["Aggravated assault"].astype(int)
raw_data2011_df2["Property Crime"] = raw_data2011_df2["Property Crime"].astype(int)
raw_data2011_df2["Burglary"] = raw_data2011_df2["Burglary"].astype(int)
raw_data2011_df2["Larceny Theft"] = raw_data2011_df2["Larceny Theft"].astype(int)
raw_data2011_df2["Motor Vehicle Theft"] = raw_data2011_df2["Motor Vehicle Theft"].astype(int)
raw_data2011_df2["Arson"] = raw_data2011_df2["Arson"].astype(int)
# Out:
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-dab9d2d551fc> in <module>
#       1 # Convert data types
#       2 raw_data2011_df2["Year"] = raw_data2011_df2["Year"].astype(int)
# ----> 3 raw_data2011_df2["Population"] = raw_data2011_df2["Population"].astype(int)
#       4 raw_data2011_df2["Violent Crime"] = raw_data2011_df2["Violent Crime"].astype(int)
#       5 raw_data2011_df2["Murder"] = raw_data2011_df2["Murder"].astype(int)
#
# ...

# %%
data2011_df
# Out:
#           State          City  Year  Population Violent Crime Murder Rape  \
# 1       ALABAMA    BIRMINGHAM  2011      213258         3,163     54  182
# 3       ALABAMA    HUNTSVILLE  2011      180972         1,521     13   51
# 7       ALABAMA    MONTGOMERY  2011      206754           707     31   38
# 9        ALASKA     ANCHORAGE  2011      296955         2,388     12  283
# 11      ARIZONA  CHANDLER      2011      239466           681      2   62
# ..          ...           ...   ...         ...           ...    ...  ...
# 551  WASHINGTON        TACOMA  2011      201510         1,507     11  125
# 553  WASHINGTON     VANCOUVER  2011      164329           633      9  102
# 555   WISCONSIN     GREEN BAY  2011      104510           371      2   52
# 557   WISCONSIN       MADISON  2011      234225           815      8   74
# 559   WISCONSIN     MILWAUKEE  2011      597426         5,951     85  195
#
#     Robbery Aggravated Assault Property Crime Burglary Larceny Theft  \
# ...

# %%
# sort by State
cleaned_data2011_df = data2011_df.sort_values(by=["State"], inplace=True)
cleaned_data2011_df
# Out:
# /Users/elysesulkey/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#export cleaned dataframe
cleaned_data2011_df.to_csv("cleaned_2011.csv", index = False)
cleaned_data2011_df.to_json("cleaned_2011.json")
